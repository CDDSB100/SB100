# %%
######### Docs TJSP ############

import glob
import fitz  # PyMuPDF
import matplotlib.pyplot as plt
import numpy as np
import time

## decisão [10, 190, 550, 810]
## inquerito [30, 200, 572, 900]
## laudo iml [30, 140, 548, 900]
## laudo médico [30, 140, 560, 900]
## laudo médico (digitalizado) [30, 140, 530, 900]
## sentença [30, 20, 572, 1000]

tipos = [
    "decisão",
    "inquérito policial",
    "laudo iml",
    "laudo médico",
    "laudo médico (digitalizado)",
    "laudo pericial",
    "laudo pericial (digitalizado)",
    "relatório de investigações",
    "relatório final",
    "relatório final digitalizado",
    "sentença"
]

for tipo in tipos:
    for s in glob.glob(f"C:/Estudos e Projetos/(2024) Dados LAI MP/separado_doc_tjsp/unificador_documentos/pasta_teste_juncao_docs/{tipo}/*.pdf")[0:1]:
        source = s.replace('\\','/')

        # Caminho para o arquivo PDF
        file_name = source

        # Abrir o documento PDF
        doc = fitz.open(file_name)
        
        # Selecionar a página que você deseja visualizar (aqui, página 0, que é a primeira página)
        page = doc.load_page(0)

        # Ajusta o valor do retângulo conforme necessário
        # esquerda, superior, direita, baixa
        rect = fitz.Rect([200, 20, 350, 1200])

        # Converter a página em uma imagem (pixmap)
        pix = page.get_pixmap(dpi=150,clip=rect)

        # Converter os samples para um array NumPy e redimensionar
        image = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)

        if image.size > 0:
            # Ajustar o tamanho da figura
            plt.figure(figsize=(10, 10))  # Ajuste o tamanho conforme necessário

            # Exibir a imagem
            plt.imshow(image)
            plt.axis('on')  # Desativa os eixos
            plt.show()
        else:
            print(f"Warning: The image array is empty for file {file_name}")
        time.sleep(1)

# %% [markdown]
# #### Docs MP

# %%
######### Docs TJSP ############

import glob
import fitz  # PyMuPDF
import matplotlib.pyplot as plt
import numpy as np
import time

## decisão [10, 190, 550, 810]
## inquerito [30, 200, 572, 900]
## laudo iml [30, 140, 548, 900]
## laudo médico [30, 140, 560, 900]
## laudo médico (digitalizado) [30, 140, 530, 900]
## sentença [30, 20, 572, 1000]

tipos = [
    "manifestacao do mp"
]

for tipo in tipos:
    for s in glob.glob(f"C:/Estudos e Projetos/(2024) Dados LAI MP/dowload_docs_mp/pdf_pedidos_arquivamento/Base Pedidos de Arquivamento MP-SP/*.pdf"):
        tipo_doc = "manifestacao do mp"
        source = s.replace('\\','/')

        # Caminho para o arquivo PDF
        file_name = source

        # Abrir o documento PDF
        doc = fitz.open(file_name)
        
        # Selecionar a página que você deseja visualizar (aqui, página 0, que é a primeira página)
        page = doc.load_page(0)

        # Ajusta o valor do retângulo conforme necessário
        # esquerda, superior, direita, baixa
        rect = fitz.Rect([200, 20, 350, 1200])

        # Converter a página em uma imagem (pixmap)
        pix = page.get_pixmap(dpi=150,clip=rect)

        # Converter os samples para um array NumPy e redimensionar
        image = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)

        if image.size > 0:
            # Ajustar o tamanho da figura
            plt.figure(figsize=(10, 10))  # Ajuste o tamanho conforme necessário

            # Exibir a imagem
            plt.imshow(image)
            plt.axis('on')  # Desativa os eixos
            plt.show()
        else:
            print(f"Warning: The image array is empty for file {file_name}")
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 51
#      49     plt.imshow(image)
#      50     plt.axis('on')  # Desativa os eixos
# ---> 51     plt.show()
#      52 else:
#      53     print(f"Warning: The image array is empty for file {file_name}")
#
# File c:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\.venv\Lib\site-packages\matplotlib\pyplot.py:614, in show(*args, **kwargs)
#     570 """
#     571 Display all open figures.
#     572
#    (...)
#     611 explicitly there.
#     612 """
#     613 _warn_if_gui_out_of_main_thread()
# --> 614 return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\.venv\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
# ...

# %%
import camelot
import matplotlib.pyplot as plt

# Caminho para o arquivo PDF
file_name = r'C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\pdf\citros.pdf'

# Usando Camelot para ler o PDF
tables = camelot.read_pdf(
    file_name,
    pages='1-end',  # Alterar para as páginas desejadas
    #flavor='stream',
    #table_area=['40, 1162, 757, 55'],
    strip_text='\r'
)

# Verificando o relatório de análise (para diagnóstico)
#print(tables[0].parsing_report)

# Exibindo a tabela com Camelot (plotando a grade da tabela)
camelot.plot(tables[0], kind='grid')

# Mostrando o gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 20
#       8 tables = camelot.read_pdf(
#       9     file_name,
#      10     pages='1-end',  # Alterar para as páginas desejadas
#    (...)
#      13     strip_text='\r'
#      14 )
#      16 # Verificando o relatório de análise (para diagnóstico)
#      17 #print(tables[0].parsing_report)
#      18
#      19 # Exibindo a tabela com Camelot (plotando a grade da tabela)
# ---> 20 camelot.plot(tables[0], kind='grid')
#      22 # Mostrando o gráfico
#      23 plt.show()
#
# File c:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\.venv\Lib\site-packages\camelot\core.py:938, in TableList.__getitem__(self, idx)
#     937 def __getitem__(self, idx):  # noqa D105
# --> 938     return self._tables[idx]
#
# IndexError: list index out of range
