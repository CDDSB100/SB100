# %% [markdown]
# #### Modelo extração de texto Marckdown e JSON

# %% [markdown]
# ##### obs.: Para usa essa lib no windows é preciso ativar o modo desenvolvedor

# %%
from docling.document_converter import DocumentConverter

source = r"C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\pdf\citros.pdf"  # document per local path or URL
converter = DocumentConverter()
result = converter.convert(source)
print(result.document.export_to_markdown())
# Out:
# ## 3.4. Citros
#
# ## (Gênero Citrus )
#
# José Antonio Quaggio ( 1 ) Dirceu Mattos Jr. ( 1 ) Rodrigo Marcelli Boaretto ( 1 ) Fernando Cesar Bachiega Zambrosi ( 1 ) Heitor Cantarella ( 1 )
#
# ## 1. Considerações gerais
#
# A citricultura  contribui  com  o  maior  volume  da  produção brasileira  de  frutas  (cerca  de  55%  do  volume  das  oito principais frutíferas), obtido  com  alta  produtividade, resultado  da  adoção  de  tecnologias  como  adensamento  de  plantio, adubação, irrigação e fertirrigação. Os citros compreendem um grande grupo de plantas do gênero Citrus spp. (laranjas, tangerinas, mexericas, limões, limas ácidas como o Tahiti e o Galego, e doces como a Lima-da-pérsia,  pomelo,  cidra,  laranja-azeda  e  toranjas)  e  outros  gêneros correlatos ( Fortunella e Poncirus ) ou híbridos da família Rutaceae. Devido à  importância  da  citricultura  para  o  agronegócio  paulista  e  o  volume de  informações  geradas  pela  pesquisa,  as  recomendações  de  manejo de  calagem  e  adubação  dos  citros  são  apresentadas  em  um  capítulo independente de outras frutíferas.
#
# ## 2. Exportação de nutrientes
#
# As  quantidades  de  nutrientes  exportadas  com  a  colheita  são indicadores importantes para o dimensionamento das adubações e para oglyph<c=3,font=/CIDFont+F8> cálculoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> eÀciênciaglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> aproveitamentoglyph<c=3,font=/CIDFont+F8> dosglyph<c=3,font=/CIDFont+F8> fertilizantesglyph<c=3,font=/CIDFont+F8> aoglyph<c=3,font=/CIDFont+F8> nívelglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> propriedade  agrícola  ou  gleba  cultivada.  A  tabela  1  apresenta  as
#
# quantidades de nutrientes exportadas com a colheita de frutas cítricas. Esses valores se aplicam para pomares com produtividades de 30 a 60 t ha -1 de frutos.
#
# Tabela 1. Conteúdo de nutrientes exportado por tonelada de fruto colhido
#
# |        | N                                            | P                                            | K                                            | Ca                                           | Mg                                           | S                                            |
# |--------|----------------------------------------------|----------------------------------------------|----------------------------------------------|----------------------------------------------|----------------------------------------------|----------------------------------------------|
# |        | kg t -1 \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ | kg t -1 \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ | kg t -1 \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ | kg t -1 \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ | kg t -1 \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ | kg t -1 \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ |
# | Citros | 1,9-2,4                                      | 0,15-0,21                                    | 1,3-2,1                                      | 0,45-0,64                                    | 0,11-0,15                                    | 0,10-0,18                                    |
# |        | B                                            | Cu                                           |                                              |                                              | Mn                                           | Zn                                           |
# |        | Fe                                           | Fe                                           | Fe                                           | Fe                                           | Fe                                           | Fe                                           |
# | Citros | 2,0-6,0                                      | 0,4-0,7                                      | 3,0-5,0                                      |                                              | 1,0-3,0                                      | 1,0-3,0                                      |
#
# ## 3. Amostragem e análise química de folha
#
# Os  citros  armazenam  grande  quantidade  de  nutrientes  na biomassa  que  podem  ser  redistribuídos,  principalmente,  para  órgãos em desenvolvimento como folhas e frutos. Assim, a análise foliar é uma ferramenta útil para complementar a análise de solo e aferir o equilíbrio nutricional da planta. Além disso, para o caso do nitrogênio (N), cujos métodos de análise de solo não têm consistência no diagnóstico, o teor do nutriente  nas  folhas  é  usado  como  critério  direto  de  avaliação  da disponibilidade de N para as plantas.
#
# ## 4. Instruções para a amostragem foliar para citros
#
# Coletar a 3ª ou 4ª folha do ramo com fruto terminal, geradas na primavera, com aproximadamente seis meses de idade, normalmente de fevereiro a março, em ramos com frutos de 2 a 4 cm de diâmetro. Amostrar peloglyph<c=3,font=/CIDFont+F8>menosglyph<c=3,font=/CIDFont+F8>20glyph<c=3,font=/CIDFont+F8>ár voresglyph<c=3,font=/CIDFont+F8>porglyph<c=3,font=/CIDFont+F8>talhão,glyph<c=3,font=/CIDFont+F8>coletandoglyph<c=3,font=/CIDFont+F8>quatroglyph<c=3,font=/CIDFont+F8>folhasglyph<c=3,font=/CIDFont+F8>nãoglyph<c=3,font=/CIDFont+F8>daniÀcadasglyph<c=3,font=/CIDFont+F8> por árvore, uma em cada quadrante e na altura mediana da copa.
#
# Pulverizações  com  adubos  foliares,  e/ou  o  uso  de  defensivos contendo  nutrientes,  podem  deixar  parte  dos  elementos  aderidos  na
#
# superfície do limbo foliar por vários meses e levar ao erro de interpretação da análise; assim, quando possível, é recomendável não coletar folhas em um intervalo mínimo 30 dias após a última pulverização. As amostras devem  ser  acondicionadas  em  sacos  de  papel  e  enviadas  para  o laboratório em período inferior a dois dias após a coleta no campo.
#
# Os valores de concentrações de nutrientes nas folhas de citros e suas interpretações estão na tabela 2.
#
# Tabela 2. Faixas  para  interpretação de teores de macro e micronutrientes nas folhas de citros, geradas na primavera, com seis meses de idade, de ramos com fruto terminal com 2 a 4 cm de diâmetro
#
# | Nutriente            | Baixo                        | Adequado                     | Alto                          |
# |----------------------|------------------------------|------------------------------|-------------------------------|
# | \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ | g kg -1 \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ | g kg -1 \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ | g kg -1 \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_  |
# | <25                  |                              | 25-30 >30                    | N: Citros geral               |
# | <20                  |                              | 20-24 >24                    | N: Limões e lima ácida Tahiti |
# | <1,2                 |                              | 1,2-1,6 >1,6                 | P                             |
# | <10                  |                              | 10-15 >15                    | K                             |
# | <35                  |                              | 35-50 >50                    | Ca                            |
# | <3,5                 |                              | 3,5-5,0 >5,0                 | Mg                            |
# | S <2,0               | 2,0-3,0                      | >3,0                         |                               |
# | \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_  | mg kg -1 \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ | mg kg -1 \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ | mg kg -1 \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_  |
# | B                    | <50                          | 50-150 >150                  |                               |
# | <10                  | 10-20                        | >20                          | Cu                            |
# | <50                  | 50-150                       | >150                         | Fe                            |
# | <30                  | 30-60                        | >60                          | Mn                            |
# | Mo <0,5              | 0,5-2,0                      | >2,0                         |                               |
# | <35                  | 35-70                        | >70                          | Zn                            |
#
# Teores altos dos micronutrientes metálicos, especialmente Cu, às vezes podem ser encontrados na análise de folha sem que esta apresente sintomas  de  toxicidade,  o  que  pode  levar  à  interpretação  errônea  do estado nutricional, pois estes nutrientes podem apenas estar aderidos à superfície da folha sem exercer papel metabólico na planta.
#
# Os teores foliares dos nutrientes não dependem unicamente da disponibilidadeglyph<c=3,font=/CIDFont+F8> doglyph<c=3,font=/CIDFont+F8> elementoglyph<c=3,font=/CIDFont+F8> noglyph<c=3,font=/CIDFont+F8> solo,glyph<c=3,font=/CIDFont+F8> poisglyph<c=3,font=/CIDFont+F8> sofremglyph<c=3,font=/CIDFont+F8> inÁuênciaglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> váriosglyph<c=3,font=/CIDFont+F8> outros  fatores  como  taxa  de  crescimento  da  planta,  idade  da  folha, combinações copa e porta-enxerto, e interações com outros nutrientes. Os teores de nutrientes com alta redistribuição dentro da planta, como N, P e K, diminuem com a idade da folha, enquanto os teores de nutriente imóveis como Ca e B, por exemplo, aumentam nas folhas mais velhas. Assim, pelos motivos citados, as folhas coletadas para análise devem ser da mesma idade daquelas que foram usadas na tabela de interpretação (Tabela 2).
#
# ## 5. Amostragem de solo em pomares
#
# A  amostragem  de  solo  deve  ser  feita  em  glebas  ou  talhões homogêneos quanto à cor e textura do solo, posição no relevo e manejo do pomar, idade das árvores, combinações de copa e porta-enxerto e produtividade.
#
# Coletar  as  amostras  nas  profundidades  de  0-20  cm  para  as recomendações de adubação e a calagem. Coletar solo na camada de 20-40 cm para o diagnóstico de barreiras químicas ao desenvolvimento dasglyph<c=3,font=/CIDFont+F8> raízes,glyph<c=3,font=/CIDFont+F8> ouglyph<c=3,font=/CIDFont+F8> seja,glyph<c=3,font=/CIDFont+F8> deÀciênciasglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> Caglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> ouglyph<c=3,font=/CIDFont+F8> excessoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> alumínio,glyph<c=3,font=/CIDFont+F8> comoglyph<c=3,font=/CIDFont+F8> também  para  aferir  movimentação  ou  perda  de  nutrientes  abaixo da  camada  com  maior  concentração  de  raízes.  Coletar  de  15  a  20 subamostras por talhão, com trados do tipo holandês ou sonda.
#
# Antes da implantação do pomar, coletar o solo nas profundidades de 0-0 cm e 20-40 cm percorrendo a área em zigue-zague. Após o plantio, em pomares não irrigados, amostrar na faixa de adubação, sendo uma subamostra coletada cerca de 50 cm para dentro e outra 50 cm para fora da projeção da copa das árvores. Para pomares fertirrigados, amostrar dentro do bulbo úmido, de 20 cm a 30 cm da linha de gotejo em direção oposta ao tronco da árvore.
#
# Amostrar o solo anualmente na camada de 0-20 cm e a cada dois anos na camada de 20-40 cm. Coletar as amostras após 2/3 da adubação anual ter sido realizada, mantendo um intervalo mínimo de 30 a 45 dias após o último parcelamento da adubação sólida.
#
# ## 6. Recomendações de adubação e calagem para os citros
#
# Introdução: As recomendações para o manejo da fertilidade do solo na citricultura paulista contemplam todo avanço obtido nas últimas duas décadas de pesquisa no Brasil. Os novos conhecimentos certamente vêm contribuindo para o grande salto em produtividade da citricultura paulista nos últimos anos, que passou de 10 t ha -1 em 1980 para 40 t ha -1 em 2020, sendo que os melhores pomares alcançam médias acima de 50 t ha -1 .
#
# Os citros têm algumas particularidades e demandas nutricionais diferenciadas,  como  o  fato  do  cálcio  ser  o  nutriente  em  maiores concentrações  nas  folhas  em  comparação  com  outras  culturas. Espécies e porta-enxertos também têm demandas diferenciadas. Entre os  avanços  recentes  destacam-se  os  ajustes  nas  recomendações  de nutrientes dos novos porta-enxertos que substituíram o limão-cravo; as novas informações sobre a resposta e o manejo de micronutrientes em citros  e  o  preparo  reduzido  solo,  com  plantio  das  mudas  em  faixas  e incorporação profunda de calcário e fósforo no sulco de plantio, o que proporciona  desenvolvimento  mais  rápido  das  mudas,  produtividade mais  precoce  e  boa  conservação  do  solo.  Outro  fator  importante  no ganho de produtividade da citricultura foi o adensamento de plantio, associado com irrigação e fertirrigação, que tem permitido aumentos de 20%glyph<c=3,font=/CIDFont+F8>aglyph<c=3,font=/CIDFont+F8>25%glyph<c=3,font=/CIDFont+F8>naglyph<c=3,font=/CIDFont+F8>eÀciênciaglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>usoglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>nutrientes.glyph<c=3,font=/CIDFont+F8>
#
# A presente tabela de recomendações leva em conta exigências de espécies e porta-enxertos, e também das características de frutas para diferentes mercados. Por exemplo, o mercado de frutas frescas requer frutosglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> maiorglyph<c=3,font=/CIDFont+F8> tamanhoglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> cascaglyph<c=3,font=/CIDFont+F8> Àrme;glyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> indústriaglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> sucos,glyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> adubação visa otimazar a produtividade por área.
#
# Espaçamento: O  adensamento  de  plantio  na  citricultura aumentou nos últimos anos devido principalmente à incidência do HLB ou greening ,  cujo  manejo pode levar à erradicação de grande número de plantas anualmente. Desta maneira, o espaçamento de plantio está sendo reduzido com o objetivo de mitigar as perdas de plantas ao longo da vida útil dos talhões. Atualmente, os espaçamentos recomendados entrelinhas de plantio variam de 6 m a 7 m, enquanto os entre plantas variam de 2 m a 3 m.
#
# Calagem: Os citros são exigentes em cálcio e produzem melhor em  solos  próximos  da  neutralidade.  A  calagem  no  plantio  merece atenção especial, pois esta é a melhor oportunidade para a incorporação do  calcário  e  para  corrigir  a  acidez  nas  camadas  mais  profundas  do solo. Antes da implantação do pomar, o calcário deve ser aplicado na faixa de plantio das mudas, com largura ao redor de 2 m, e incorporado com grade pesada o mais profundamente possível. Aplicar calcário para elevar  a  saturação  por  bases (V)  a  70%  e  manter  o  teor  de  magnésio em pelo menos 8 mmol c dm -3 na camada de 0-20 cm de profundidade. Caso  a  saturação  por  bases  da  camada  de  20-40  cm  seja  inferior  a 25%, aumentar em 50% a dose de calcário aplicado nesta faixa. Além da calagem na faixa, uma dose adicional de calcário deve ser aplicada também no sulco de plantio, à taxa de 0,5 kg ha -1 por metro de sulco, e posteriormente misturado ao solo até a profundidade de 25 cm a 30 cm com subsolador de três hastes, o qual também realiza a incorporação do fósforo em profundidade, como descrito adiante. O restante da área dos  talhões,  ou  seja,  o  meio  das  ruas,  deverá  receber  a  mesma  dose de  calcário,  em  t  ha -1 ,  recomendada  para  a  faixa  de  plantio,  porém  a incorporação deverá ser feita em ruas alternadas para a maior proteção do solo contra a erosão.
#
# Em pomares já plantados, cerca de 70% da dose de calcário deve ser aplicada sob a projeção das copas das plantas e o restante na rua. Em pomares fertirrigados, toda a dose deve ser aplicada sob a projeção da copa,glyph<c=3,font=/CIDFont+F8>devidoglyph<c=3,font=/CIDFont+F8>àglyph<c=3,font=/CIDFont+F8>acidiÀcaçãoglyph<c=3,font=/CIDFont+F8>doglyph<c=3,font=/CIDFont+F8>sologlyph<c=3,font=/CIDFont+F8>serglyph<c=3,font=/CIDFont+F8>maisglyph<c=3,font=/CIDFont+F8>intensaglyph<c=3,font=/CIDFont+F8>nestaglyph<c=3,font=/CIDFont+F8>região.glyph<c=3,font=/CIDFont+F8>
#
# Gessagem: Em pomares instalados, da mesma forma que o calcário, o gesso deve ser distribuído de forma localizada na faixa de adubação, quando os teores foliares de cálcio forem menores que 35 g kg -1 . Assim, aplicar 1,0, 1,5 ou 2,0 t ha -1 de gesso, respectivamente, para solos arenosos (<200 g kg -1 de  argila),  de  textura  média  (200-400  g  kg -1 de  argila)  ou argilosos (>400 g kg -1 de argila).
#
# Adubação de sulco de plantio: Aplicar 90 g de P 2 O 5 por metro de sulco, que de acordo com o espaçamento varia de 120 a 160 kg ha -1 de P 2 O 5 . A experiência de vários anos somada aos resultados de pesquisas tem demonstrado as vantagens da adubação desta aplicação extra de P em profundidade no sulco de plantio após a calagem. O citricultor deve dar preferência a fontes de fosfatos solúveis em água, e se possível, contendo zinco. Esta é a única oportunidade para aplicar P em profundidade. Para
#
# facilitar a incorporação de calcário no sulco e simultaneamente aplicar P em profundidade, um subsolador triplo, dotado de dispositivo capaz de aplicar P junto das suas hastes, pode ser utilizado.
#
# Adubaçãoglyph<c=3,font=/CIDFont+F5> deglyph<c=3,font=/CIDFont+F5> formação: Durante a fase de formação do pomar, até o quarto ano, as doses de N, P 2 O 5 e  K 2 O recomendadas levam em conta  a  idade  do  pomar  e  os  resultados  da  análise  de  solo  para  P  e K para atender às necessidades de crescimento da copa e o início de produção de frutos (Tabela 3). Ajustes nas doses recomendadas de P e K devem ser feitos levando em conta o porta-enxerto plantado. As doses de N e K devem ser parceladas de 4 a 6 vezes, entre setembro a março. Maior número de parcelamentos é necessário nos primeiros anos após o plantio das mudas. A aplicação de P deve ser preferencialmente em dose única, antes do primeiro parcelamento de N e K, geralmente entre os meses de julho a agosto.
#
# No  passado,  as  recomendações  de  nutrientes  para  o  período de formação dos citros eram feitas para plantas até a idade de 4 a 5 anos.  Entretanto,  o  aumento  da  densidade  de  plantio  e  plantas  mais próximasglyph<c=3,font=/CIDFont+F8> entreglyph<c=3,font=/CIDFont+F8> si,glyph<c=3,font=/CIDFont+F8> permitiuglyph<c=3,font=/CIDFont+F8> ganhosglyph<c=3,font=/CIDFont+F8> naglyph<c=3,font=/CIDFont+F8> eÀciênciaglyph<c=3,font=/CIDFont+F8> fer tilizante.glyph<c=3,font=/CIDFont+F8> Alémglyph<c=3,font=/CIDFont+F8> disso,glyph<c=3,font=/CIDFont+F8> com  o  adensamento  de  plantio,  o  antigo  cálculo  de  dose  de  adubo por planta resultava em doses por área muito elevadas, o que gerava plantas  excessivamente  vigorosas.  Para  superar  esses  problemas,  as recomendações  atuais  para  a  formação  dos  citros  são  calculadas  por área, conforme a tabela abaixo.
#
# Tabela 3. Recomendações de adubação para citros em formação, em função da idade da planta e da análise do solo (1)
#
# | Idade   | N              | P resina, mg dm -3                  | P resina, mg dm -3                  | P resina, mg dm -3                  | K +  trocável, mmol c  dm -3       | K +  trocável, mmol c  dm -3       | K +  trocável, mmol c  dm -3       |
# |---------|----------------|-------------------------------------|-------------------------------------|-------------------------------------|------------------------------------|------------------------------------|------------------------------------|
# |         |                | <16                                 | 16-40                               | >40                                 | <1,6                               | 1,6-3,0                            | >3,0                               |
# | Anos    | kg ha -1  de N | \_\_\_\_\_\_  kg ha -1  de P 2 O 5 \_\_\_\_\_\_ | \_\_\_\_\_\_  kg ha -1  de P 2 O 5 \_\_\_\_\_\_ | \_\_\_\_\_\_  kg ha -1  de P 2 O 5 \_\_\_\_\_\_ | \_\_\_\_\_\_  kg ha -1  de K 2 O  \_\_\_\_\_\_ | \_\_\_\_\_\_  kg ha -1  de K 2 O  \_\_\_\_\_\_ | \_\_\_\_\_\_  kg ha -1  de K 2 O  \_\_\_\_\_\_ |
# | 0-1     | 70             | 15                                  | 15                                  | 15                                  | 15                                 | 10                                 | 0                                  |
# | 1-2     | 100            | 60                                  | 45                                  | 30                                  | 50                                 | 30                                 | 10                                 |
# | 2-3     | 140            | 90                                  | 60                                  | 45                                  | 90                                 | 60                                 | 40                                 |
# | 3-4     | 180            | 120                                 | 90                                  | 60                                  | 120                                | 90                                 | 60                                 |
#
# Adubação de produção: A adubação para pomares em produção leva  em  conta,  além  da  disponibilidade  de  nutrientes  no  solo,  os teores foliares de N e a produtividade esperada. Foram estabelecidas recomendações da adubação N, P e K para os grupos de variedades de laranjas, considerando a qualidade e o destino da fruta, que pode ser para a indústria (Tabela 4) ou para o mercado in natura (Tabela 5). A tabela 5 também deve ser utilizada para as tangerinas e o Tangor Murcott, os quais possuem demandas por nutrientes semelhantes às das laranjas  para consumo in natura. A lima ácida Tahiti e os limões verdadeiros têm recomendações distintas e para estes, a tabela 6 deve serglyph<c=3,font=/CIDFont+F8> utilizada.glyph<c=3,font=/CIDFont+F8>Aglyph<c=3,font=/CIDFont+F8> limaglyph<c=3,font=/CIDFont+F8> ácidaglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> osglyph<c=3,font=/CIDFont+F8> limõesglyph<c=3,font=/CIDFont+F8> sãoglyph<c=3,font=/CIDFont+F8> maisglyph<c=3,font=/CIDFont+F8> eÀcientesglyph<c=3,font=/CIDFont+F8> noglyph<c=3,font=/CIDFont+F8> usoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> N,glyph<c=3,font=/CIDFont+F8> razão pela qual as faixas de interpretação de N foliar são menores do que as de outros citros.
#
# A  adubação  deve  ser  feita  no  período  das  águas  (setembro  a março),  pois  a  demanda  por  nutrientes  pelos  citros  é  maior  no  início daglyph<c=3,font=/CIDFont+F8> primavera,glyph<c=3,font=/CIDFont+F8> quandoglyph<c=3,font=/CIDFont+F8> ocorreglyph<c=3,font=/CIDFont+F8> oglyph<c=3,font=/CIDFont+F8> Áuxoglyph<c=3,font=/CIDFont+F8> maisglyph<c=3,font=/CIDFont+F8> intensoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> vegetação,glyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> seglyph<c=3,font=/CIDFont+F8> estendeglyph<c=3,font=/CIDFont+F8> atéglyph<c=3,font=/CIDFont+F8> oglyph<c=3,font=/CIDFont+F8> inícioglyph<c=3,font=/CIDFont+F8> doglyph<c=3,font=/CIDFont+F8> outono,glyph<c=3,font=/CIDFont+F8> quandoglyph<c=3,font=/CIDFont+F8> deveglyph<c=3,font=/CIDFont+F8> haverglyph<c=3,font=/CIDFont+F8> reser vaglyph<c=3,font=/CIDFont+F8> suÀcienteglyph<c=3,font=/CIDFont+F8> e  equilíbrio  de  nutrientes  na  biomassa  das  plantas  para  garantir  os processosglyph<c=3,font=/CIDFont+F8>normaisglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>diferenciaçãoglyph<c=3,font=/CIDFont+F8>Áoral,glyph<c=3,font=/CIDFont+F8>Áoraçãoglyph<c=3,font=/CIDFont+F8>eglyph<c=3,font=/CIDFont+F8>Àxaçãoglyph<c=3,font=/CIDFont+F8>dosglyph<c=3,font=/CIDFont+F8>frutos.glyph<c=3,font=/CIDFont+F8>
#
# O parcelamento das doses de N e K é feito em 3 ou 4 aplicações duranteglyph<c=3,font=/CIDFont+F8> oglyph<c=3,font=/CIDFont+F8> ano,glyph<c=3,font=/CIDFont+F8> oglyph<c=3,font=/CIDFont+F8> queglyph<c=3,font=/CIDFont+F8> aumentaglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> eÀciênciaglyph<c=3,font=/CIDFont+F8> daglyph<c=3,font=/CIDFont+F8> adubação,glyph<c=3,font=/CIDFont+F8> porglyph<c=3,font=/CIDFont+F8> reduzirglyph<c=3,font=/CIDFont+F8> asglyph<c=3,font=/CIDFont+F8> perdas de nutrientes no solo com a água de drenagem, principalmente em solos arenosos, e por adequar a demanda de nutrientes em diferentes períodos do desenvolvimento das plantas. Aplicar 40% do N e K na época doglyph<c=3,font=/CIDFont+F8> Áorescimentoglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> oglyph<c=3,font=/CIDFont+F8> restanteglyph<c=3,font=/CIDFont+F8> divididoglyph<c=3,font=/CIDFont+F8> entreglyph<c=3,font=/CIDFont+F8> outubroglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> marçoglyph<c=3,font=/CIDFont+F8> doglyph<c=3,font=/CIDFont+F8> anoglyph<c=3,font=/CIDFont+F8> seguinte. O P pode ser aplicado numa só vez, no primeiro parcelamento, especialmente quando o solo do pomar apresentar teor de P abaixo de 15 mg dm -3 .
#
# Em variedades precoces, tais como Hamlin, Valência Americana, Rubi e Westin, maior proporção de adubo deve ser aplicada mais cedo: 40% na primeira, 40% na segunda e 20% na última parcela, a qual deverá serglyph<c=3,font=/CIDFont+F8>realizadaglyph<c=3,font=/CIDFont+F8>atéglyph<c=3,font=/CIDFont+F8>oglyph<c=3,font=/CIDFont+F8>Ànalglyph<c=3,font=/CIDFont+F8>doglyph<c=3,font=/CIDFont+F8>verão.
#
# Tabela 4. Recomendações de adubação de laranjas para a indústria, em função das análises de solo e folhas e da produtividade esperada
#
# | Produtivi- dade  esperada   | Nglyph<c=3,font=/CIDFont+F5>foliar,glyph<c=3,font=/CIDFont+F5>gglyph<c=3,font=/CIDFont+F5>kg -1   | Nglyph<c=3,font=/CIDFont+F5>foliar,glyph<c=3,font=/CIDFont+F5>gglyph<c=3,font=/CIDFont+F5>kg -1   | Nglyph<c=3,font=/CIDFont+F5>foliar,glyph<c=3,font=/CIDFont+F5>gglyph<c=3,font=/CIDFont+F5>kg -1   | P resina, mg dm -3          | P resina, mg dm -3          | P resina, mg dm -3          | K +  trocável, mmol c  dm -3   | K +  trocável, mmol c  dm -3   | K +  trocável, mmol c  dm -3   |
# |-----------------------------|---------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------|-----------------------------|-----------------------------|-----------------------------|--------------------------------|--------------------------------|--------------------------------|
# | Produtivi- dade  esperada   | <25                                                                                               | 25-30                                                                                             | >30                                                                                               | <16                         | 16-40                       | >40                         | <1,6                           | 1,6-3,0                        | >3,0 (1)                       |
# | t ha -1                     | \_\_\_  kg ha -1  de N  \_\_\_                                                                          | \_\_\_  kg ha -1  de N  \_\_\_                                                                          | \_\_\_  kg ha -1  de N  \_\_\_                                                                          | \_\_  kg ha -1  de P 2 O 5 \_\_ | \_\_  kg ha -1  de P 2 O 5 \_\_ | \_\_  kg ha -1  de P 2 O 5 \_\_ | \_\_\_\_  kg ha -1  de K 2 O  \_\_\_\_ | \_\_\_\_  kg ha -1  de K 2 O  \_\_\_\_ | \_\_\_\_  kg ha -1  de K 2 O  \_\_\_\_ |
# | <30                         | 160                                                                                               | 140                                                                                               | 90                                                                                                | 80                          | 60                          | 30                          | 100                            | 80                             | 60                             |
# | 31-40                       | 180                                                                                               | 160                                                                                               | 120                                                                                               | 100                         | 80                          | 40                          | 120                            | 100                            | 80                             |
# | 41-50                       | 200                                                                                               | 180                                                                                               | 160                                                                                               | 120                         | 100                         | 50                          | 160                            | 140                            | 100                            |
# | 51-60                       | 220                                                                                               | 200                                                                                               | 180                                                                                               | 140                         | 120                         | 60                          | 180                            | 160                            | 120                            |
# | >60                         | 260                                                                                               | 220                                                                                               | 200                                                                                               | 160                         | 140                         | 70                          | 200                            | 180                            | 140                            |
#
# Tabela  5. Recomendações  de  adubação  de  laranjas  para  consumo  in  natura, tangerinas  e  tangor  Murcott,  em  função  das  análises  do  solo  e  folhas  e  da produtividade esperada
#
# | Produtivi- dade  esperada   | Nglyph<c=3,font=/CIDFont+F5>foliar,glyph<c=3,font=/CIDFont+F5>gglyph<c=3,font=/CIDFont+F5>kg -1   | Nglyph<c=3,font=/CIDFont+F5>foliar,glyph<c=3,font=/CIDFont+F5>gglyph<c=3,font=/CIDFont+F5>kg -1   | Nglyph<c=3,font=/CIDFont+F5>foliar,glyph<c=3,font=/CIDFont+F5>gglyph<c=3,font=/CIDFont+F5>kg -1   | P resina, mg dm -3   | P resina, mg dm -3   | P resina, mg dm -3   | K +  trocável, mmol c  dm -3   | K +  trocável, mmol c  dm -3   | K +  trocável, mmol c  dm -3   |
# |-----------------------------|---------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------|----------------------|----------------------|----------------------|--------------------------------|--------------------------------|--------------------------------|
# | Produtivi- dade  esperada   | <25                                                                                               | 25-30                                                                                             | >30                                                                                               | <16                  | 16-40                | >40                  | <1,6                           | 1,6-3,0                        | >3,0 (1)                       |
# | t ha -1                     | \_\_\_  kg ha -1                                                                                     | de N                                                                                              | \_\_\_                                                                                               | \_\_  kg ha            | -1  de P 2           | O 5 \_\_               | \_\_\_\_  kg ha -1  de K           |                                | 2 O  \_\_\_\_                      |
# | <30                         | 120                                                                                               | 100                                                                                               | 80                                                                                                | 80                   | 60                   | 30                   | 120                            | 100                            | 80                             |
# | 31-40                       | 140                                                                                               | 120                                                                                               | 100                                                                                               | 100                  | 80                   | 40                   | 160                            | 140                            | 100                            |
# | 41-50                       | 180                                                                                               | 160                                                                                               | 120                                                                                               | 120                  | 100                  | 50                   | 200                            | 180                            | 140                            |
# | >50                         | 200                                                                                               | 180                                                                                               | 160                                                                                               | 140                  | 120                  | 60                   | 220                            | 200                            | 160                            |
#
# Tabela 6. Recomendações de adubação para lima ácida Tahiti e limões verdadeiros, em função das análises do solo e folhas e da produtividade esperada
#
# | Produtivi- dade  esperada   | Nglyph<c=3,font=/CIDFont+F5>f oliar,glyph<c=3,font=/CIDFont+F5>gglyph<c=3,font=/CIDFont+F5>kg -1   | Nglyph<c=3,font=/CIDFont+F5>f oliar,glyph<c=3,font=/CIDFont+F5>gglyph<c=3,font=/CIDFont+F5>kg -1   | Nglyph<c=3,font=/CIDFont+F5>f oliar,glyph<c=3,font=/CIDFont+F5>gglyph<c=3,font=/CIDFont+F5>kg -1   | P resina, mg dm -3           | P resina, mg dm -3           | P resina, mg dm -3           | K +  trocável, mmol c  dm -3   | K +  trocável, mmol c  dm -3   | K +  trocável, mmol c  dm -3   |
# |-----------------------------|----------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------|------------------------------|------------------------------|------------------------------|--------------------------------|--------------------------------|--------------------------------|
# | Produtivi- dade  esperada   | <20                                                                                                | 20-24                                                                                              | >24                                                                                                | <16                          | 16-40                        | >40                          | <1,6                           | 1,6-3,0                        | >3,0 (1)                       |
# | t ha -1                     | \_\_\_\_  kg ha -1  de N  \_\_\_\_                                                                         | \_\_\_\_  kg ha -1  de N  \_\_\_\_                                                                         | \_\_\_\_  kg ha -1  de N  \_\_\_\_                                                                         | \_\_  kg ha -1  de P 2 O 5  \_\_ | \_\_  kg ha -1  de P 2 O 5  \_\_ | \_\_  kg ha -1  de P 2 O 5  \_\_ | \_\_\_\_  kg ha -1  de K 2 O  \_\_\_\_ | \_\_\_\_  kg ha -1  de K 2 O  \_\_\_\_ | \_\_\_\_  kg ha -1  de K 2 O  \_\_\_\_ |
# | <30                         | 100                                                                                                | 80                                                                                                 | 60                                                                                                 | 60                           | 40                           | 20                           | 140                            | 120                            | 100                            |
# | 31-40                       | 120                                                                                                | 100                                                                                                | 80                                                                                                 | 80                           | 60                           | 30                           | 160                            | 140                            | 120                            |
# | 41-50                       | 160                                                                                                | 140                                                                                                | 100                                                                                                | 100                          | 80                           | 40                           | 200                            | 180                            | 160                            |
# | 51-60                       | 180                                                                                                | 160                                                                                                | 120                                                                                                | 120                          | 100                          | 50                           | 240                            | 220                            | 180                            |
# | >60                         | 220                                                                                                | 180                                                                                                | 160                                                                                                | 140                          | 120                          | 60                           | 260                            | 240                            | 200                            |
#
# Adubação  com  micronutrientes: Os  sintomas  visuais  de deÀciênciaglyph<c=3,font=/CIDFont+F8> B,glyph<c=3,font=/CIDFont+F8> Znglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> Mnglyph<c=3,font=/CIDFont+F8> sãoglyph<c=3,font=/CIDFont+F8> osglyph<c=3,font=/CIDFont+F8> maisglyph<c=3,font=/CIDFont+F8> frequentesglyph<c=3,font=/CIDFont+F8> emglyph<c=3,font=/CIDFont+F8> pomaresglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> citros.glyph<c=3,font=/CIDFont+F8> Aglyph<c=3,font=/CIDFont+F8> deÀciênciaglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> Cuglyph<c=3,font=/CIDFont+F8> églyph<c=3,font=/CIDFont+F8> maisglyph<c=3,font=/CIDFont+F8> comumglyph<c=3,font=/CIDFont+F8> duranteglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> formaçãoglyph<c=3,font=/CIDFont+F8> doglyph<c=3,font=/CIDFont+F8> pomar,glyph<c=3,font=/CIDFont+F8> umaglyph<c=3,font=/CIDFont+F8> vez que fungicidas cúpricos praticamente não são aplicados nessa fase. DeÀciênciaglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>Cuglyph<c=3,font=/CIDFont+F8>tambémglyph<c=3,font=/CIDFont+F8>podeglyph<c=3,font=/CIDFont+F8>serglyph<c=3,font=/CIDFont+F8>induzidaglyph<c=3,font=/CIDFont+F8>porglyph<c=3,font=/CIDFont+F8>excessoglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>N.
#
# Em  plantas  com  idade  inferior  a  4  anos,  recomenda-se  4  a  6 aplicações anuais, entre setembro a maio, de B, Cu, Mn e Zn nas folhas. Em pomares em produção realizar de  3  a  4  pulverizações  com  Mn  e Zn,glyph<c=3,font=/CIDFont+F8> doglyph<c=3,font=/CIDFont+F8> inícioglyph<c=3,font=/CIDFont+F8> daglyph<c=3,font=/CIDFont+F8> primaveraglyph<c=3,font=/CIDFont+F8> atéglyph<c=3,font=/CIDFont+F8> oglyph<c=3,font=/CIDFont+F8> Ànalglyph<c=3,font=/CIDFont+F8> dasglyph<c=3,font=/CIDFont+F8> chuvas,glyph<c=3,font=/CIDFont+F8> procurandoglyph<c=3,font=/CIDFont+F8> atingirglyph<c=3,font=/CIDFont+F8> asglyph<c=3,font=/CIDFont+F8> brotações novas e folhas expandidas. A adubação foliar com B, que pode ser juntada à de Mn e Zn, deve ser praticada somente como complemento à  adubação  via  solo,  geralmente  em  pomares  em  formação,  pois  a eÀciênciaglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>usoglyph<c=3,font=/CIDFont+F8>desseglyph<c=3,font=/CIDFont+F8>nutrienteglyph<c=3,font=/CIDFont+F8>églyph<c=3,font=/CIDFont+F8>bemglyph<c=3,font=/CIDFont+F8>maiorglyph<c=3,font=/CIDFont+F8>quandoglyph<c=3,font=/CIDFont+F8>aplicadoglyph<c=3,font=/CIDFont+F8>noglyph<c=3,font=/CIDFont+F8>solo.
#
# A  aplicação  de  B  deve  ser  feita  preferencialmente  via  solo, parcelado  em  2  ou  3  vezes,  na  forma  de  ácido  bórico  dissolvido  na solução  de  herbicidas  de  contato,  como  o  glifosato,  que  constitui  a formaglyph<c=3,font=/CIDFont+F8>maisglyph<c=3,font=/CIDFont+F8>práticaglyph<c=3,font=/CIDFont+F8>eglyph<c=3,font=/CIDFont+F8>eÀcienteglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>aplicaçãoglyph<c=3,font=/CIDFont+F8>doglyph<c=3,font=/CIDFont+F8>nutriente.glyph<c=3,font=/CIDFont+F8>Geralmenteglyph<c=3,font=/CIDFont+F8>sãoglyph<c=3,font=/CIDFont+F8> feitas de 2 a 3 aplicações de herbicidas por ano, com o volume de calda de cerca de 200 L ha -1 de área tratada, na qual a dose de 1 kg ha -1 de B (6 kg ha -1 de  ácido bórico) é facilmente dissolvida. Aplicar 2 kg ha -1
#
# de B,  independentemente da idade do pomar, com maior número de parcelamentos em pomares recém-plantados. Quando o solo possuir teor de B abaixo de 0,6 mg dm -3 ou o porta-enxerto for o citrumelo Swingle, que é mais exigente em B, aumentar a dose anual para 3 kg ha -1 de B.
#
# As fontes mais recomendadas de micronutrientes metálicos para aplicação foliar são sais solúveis formados com íons sulfato, cloreto ou nitrato. Para o Cu, a mistura de sulfato e hidróxido tem sido a forma mais eÀcienteglyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> fornecerglyph<c=3,font=/CIDFont+F8> oglyph<c=3,font=/CIDFont+F8> nutrienteglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> evitarglyph<c=3,font=/CIDFont+F8> Àtoxicidadeglyph<c=3,font=/CIDFont+F8> devidoglyph<c=3,font=/CIDFont+F8> aoglyph<c=3,font=/CIDFont+F8> usoglyph<c=3,font=/CIDFont+F8> exclusivo na forma de sulfato. É importante ressaltar que o oxicloreto de Cu,glyph<c=3,font=/CIDFont+F8> comumenteglyph<c=3,font=/CIDFont+F8> utilizadoglyph<c=3,font=/CIDFont+F8> comoglyph<c=3,font=/CIDFont+F8> fungicida,glyph<c=3,font=/CIDFont+F8> temglyph<c=3,font=/CIDFont+F8> eÀciênciaglyph<c=3,font=/CIDFont+F8> limitadaglyph<c=3,font=/CIDFont+F8> comoglyph<c=3,font=/CIDFont+F8> fonte do nutriente.
#
# As  soluções  para  pulverização  foliar  são  preparadas  com  ureia como coadjuvante (ureia a 2,5 g L -1 ) e os micronutrientes, na forma de sais de sulfato e ácido bórico nas seguintes concentrações (em mg L -1 de cada nutriente): B (200 a 300), Cu (100 a 125) Mn (300 a 700) e Zn (500 a 1.000). Nessa solução, para cada 1 kg de sulfato de Cu (pentahidratado) acrescentar  1,5  kg  de  hidróxido  de  Cu.  Essas  concentrações  foram deÀnidasglyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> fornecerglyph<c=3,font=/CIDFont+F8> anualmente,glyph<c=3,font=/CIDFont+F8> emglyph<c=3,font=/CIDFont+F8> trêsglyph<c=3,font=/CIDFont+F8> aplicaçõesglyph<c=3,font=/CIDFont+F8> foliares,glyph<c=3,font=/CIDFont+F8> asglyph<c=3,font=/CIDFont+F8> seguintes quantidades de micronutrientes: Cu (1,5 a 3,0 kg ha -1 , sulfato + hidróxido), Mn (1,8 a 4,2 kg ha -1 ) e Zn (3,0 a 6,0 kg ha -1 ). O volume ideal de calda para a aplicação desses micronutrientes é de aproximadamente 2.000 L ha -1 .
#
# As menores concentrações de micronutrientes das recomendações acima são para a adubação de manutenção, enquanto as maiores são paraglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> correçãoglyph<c=3,font=/CIDFont+F8> dosglyph<c=3,font=/CIDFont+F8> sintomasglyph<c=3,font=/CIDFont+F8> visíveisglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> deÀciência.glyph<c=3,font=/CIDFont+F8> Asglyph<c=3,font=/CIDFont+F8> soluçõesglyph<c=3,font=/CIDFont+F8> maisglyph<c=3,font=/CIDFont+F8> concentradas devem ser aplicadas durante as horas mais frescas do dia ou à noite, evitando também mistura com óleos mineral ou vegetal para não causar queimaduras em folhas e frutos.
#
# Para as fontes de micronutrientes nas formas de cloreto ou nitrato, as concentrações acima indicadas devem ser reduzidas de 2 a 3 vezes; portanto,  número  maior  de  aplicações  será  necessário  para  manter  a dose anual do nutriente desejada.
#
# Adubaçãoglyph<c=3,font=/CIDFont+F5> foliarglyph<c=3,font=/CIDFont+F5> complementar: O  Mg  tem  sido  um nutriente pouco utilizado no manejo da adubação dos citros, apesar dos resultados de pesquisa que demonstram sua importância para a nutrição de plantas, aumento  da  produtividade  e  qualidade  dos  produtos.  A  adubação
#
# foliarglyph<c=3,font=/CIDFont+F8> comglyph<c=3,font=/CIDFont+F8> oglyph<c=3,font=/CIDFont+F8> Mgglyph<c=3,font=/CIDFont+F8> églyph<c=3,font=/CIDFont+F8> umaglyph<c=3,font=/CIDFont+F8> estratégiaglyph<c=3,font=/CIDFont+F8> eÀcienteglyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> corrigirglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> deÀciênciaglyph<c=3,font=/CIDFont+F8> desse nutriente em citros, principalmente pela facilidade de aplicação e possibilidade de misturas com outros produtos na calda de pulverização. Recomenda-se  a  aplicação  de  solução  com  5-10  kg  de  sulfato  de magnésio hidratado por 2.000 L da calda de pulverização, juntamente com as aplicações de micronutrientes.
#
# Experimentos recentes em condições controladas com citros têm demonstradoglyph<c=3,font=/CIDFont+F8> queglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> adiçãoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> Moglyph<c=3,font=/CIDFont+F8> aumentaglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> eÀciênciaglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> usoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> N.glyph<c=3,font=/CIDFont+F8> Essas respostas poderão ocorrer em pomares com altas produtividades, em solos com acidez moderada, arenosos e com baixo teor de matéria orgânica.glyph<c=3,font=/CIDFont+F8> Aglyph<c=3,font=/CIDFont+F8> adubaçãoglyph<c=3,font=/CIDFont+F8> foliarglyph<c=3,font=/CIDFont+F8> églyph<c=3,font=/CIDFont+F8> tambémglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> formaglyph<c=3,font=/CIDFont+F8> maisglyph<c=3,font=/CIDFont+F8> eÀcienteglyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> fornecer Mo para os citros. Nessas condições, recomenda-se de 2 a 3 aplicações anuais de solução contendo de 20 a 40 mg L -1 de Mo, o que corresponde aproximadamente de 100 a 200 g de molibdato de amônio ou de sódio por 2.000 L de calda.

# %%
from transformers import AutoTokenizer

from docling.chunking import HybridChunker

EMBED_MODEL_ID = "sentence-transformers/all-MiniLM-L6-v2"
MAX_TOKENS = 64  # set to a small number for illustrative purposes

tokenizer = AutoTokenizer.from_pretrained(EMBED_MODEL_ID)

chunker = HybridChunker(
    tokenizer=tokenizer,  # instance or model name, defaults to "sentence-transformers/all-MiniLM-L6-v2"
    max_tokens=MAX_TOKENS,  # optional, by default derived from `tokenizer`
    merge_peers=True,  # optional, defaults to True
)
chunk_iter = chunker.chunk(dl_doc=doc)
chunks = list(chunk_iter)

# %%
from transformers import AutoTokenizer
from docling.document_converter import DocumentConverter
from docling.chunking import HybridChunker

conv_res = DocumentConverter().convert(r"C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\pdf\citros.pdf")
doc = conv_res.document

EMBED_MODEL_ID = "sentence-transformers/all-MiniLM-L6-v2"
MAX_TOKENS = 300  # set to a small number for illustrative purposes

tokenizer = AutoTokenizer.from_pretrained(EMBED_MODEL_ID)

chunker = HybridChunker(
    tokenizer=tokenizer,  # instance or model name, defaults to "sentence-transformers/all-MiniLM-L6-v2"
    max_tokens=MAX_TOKENS,  # optional, by default derived from `tokenizer`
    merge_peers=True,  # optional, defaults to True
)
chunk_iter = chunker.chunk(dl_doc=doc)
chunks = list(chunk_iter)

for i, chunk in enumerate(chunks):
    print(f"=== {i} ===")
    txt_tokens = len(tokenizer.tokenize(chunk.text, max_length=None))
    print(f"chunk.text ({txt_tokens} tokens):\n{repr(chunk.text)}")

    ser_txt = chunker.serialize(chunk=chunk)
    ser_tokens = len(tokenizer.tokenize(ser_txt, max_length=None))
    print(f"chunker.serialize(chunk) ({ser_tokens} tokens):\n{repr(ser_txt)}")

    print()
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1234 > 512). Running this sequence through the model will result in indexing errors
# === 0 ===
# chunk.text (3 tokens):
# 'Citros'
# chunker.serialize(chunk) (3 tokens):
# 'Citros'
#
# === 1 ===
# chunk.text (46 tokens):
# 'José Antonio Quaggio ( 1 ) Dirceu Mattos Jr. ( 1 ) Rodrigo Marcelli Boaretto ( 1 ) Fernando Cesar Bachiega Zambrosi ( 1 ) Heitor Cantarella ( 1 )'
# chunker.serialize(chunk) (51 tokens):
# '(Gênero Citrus )\nJosé Antonio Quaggio ( 1 ) Dirceu Mattos Jr. ( 1 ) Rodrigo Marcelli Boaretto ( 1 ) Fernando Cesar Bachiega Zambrosi ( 1 ) Heitor Cantarella ( 1 )'
#
# === 2 ===
# chunk.text (277 tokens):
# 'A citricultura  contribui  com  o  maior  volume  da  produção brasileira  de  frutas  (cerca  de  55%  do  volume  das  oito principais frutíferas), obtido  com  alta  produtividade, resultado  da  adoção  de  tecnologias  como  adensamento  de  plantio, adubação, irrigação e fertirrigação. Os citros compreendem um grande grupo de plantas do gênero Citrus spp. (laranjas, tangerinas, mexericas, limões, limas ácidas como o Tahiti e o Galego, e doces como a Lima-da-pérsia,  pomelo,  cidra,  laranja-azeda  e  toranjas)  e  outros  gêneros correlatos ( Fortunella e Poncirus ) ou híbridos da família Rutaceae. Devido à  importância  da  citricultura  para  o  agronegócio  paulista  e  o  volume de  informações  geradas  pela  pesquisa,  as  recomendações  de  manejo de  calagem  e  adubação  dos  citros  são  apresentadas  em  um  capítulo independente de outras frutíferas.'
# chunker.serialize(chunk) (283 tokens):
# '1. Considerações gerais\nA citricultura  contribui  com  o  maior  volume  da  produção brasileira  de  frutas  (cerca  de  55%  do  volume  das  oito principais frutíferas), obtido  com  alta  produtividade, resultado  da  adoção  de  tecnologias  como  adensamento  de  plantio, adubação, irrigação e fertirrigação. Os citros compreendem um grande grupo de plantas do gênero Citrus spp. (laranjas, tangerinas, mexericas, limões, limas ácidas como o Tahiti e o Galego, e doces como a Lima-da-pérsia,  pomelo,  cidra,  laranja-azeda  e  toranjas)  e  outros  gêneros correlatos ( Fortunella e Poncirus ) ou híbridos da família Rutaceae. Devido à  importância  da  citricultura  para  o  agronegócio  paulista  e  o  volume de  informações  geradas  pela  pesquisa,  as  recomendações  de  manejo de  calagem  e  adubação  dos  citros  são  apresentadas  em  um  capítulo independente de outras frutíferas.'
#
# === 3 ===
# chunk.text (292 tokens):
# 'As  quantidades  de  nutrientes  exportadas  com  a  colheita  são indicadores importantes para o dimensionamento das adubações e para oglyph<c=3,font=/CIDFont+F8> cálculoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> eÀciênciaglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> aproveitamentoglyph<c=3,font=/CIDFont+F8> dosglyph<c=3,font=/CIDFont+F8> fertilizantesglyph<c=3,font=/CIDFont+F8> aoglyph<c=3,font=/CIDFont+F8> nívelglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> propriedade  agrícola  ou  gleba  cultivada.  A  tabela  1  apresenta  as\n( 1 ) Instituto Agronômico (IAC), Campinas (SP).\nB-100, 2022'
# chunker.serialize(chunk) (300 tokens):
# '2. Exportação de nutrientes\nAs  quantidades  de  nutrientes  exportadas  com  a  colheita  são indicadores importantes para o dimensionamento das adubações e para oglyph<c=3,font=/CIDFont+F8> cálculoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> eÀciênciaglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> aproveitamentoglyph<c=3,font=/CIDFont+F8> dosglyph<c=3,font=/CIDFont+F8> fertilizantesglyph<c=3,font=/CIDFont+F8> aoglyph<c=3,font=/CIDFont+F8> nívelglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> propriedade  agrícola  ou  gleba  cultivada.  A  tabela  1  apresenta  as\n( 1 ) Instituto Agronômico (IAC), Campinas (SP).\nB-100, 2022'
#
# === 4 ===
# chunk.text (104 tokens):
# '187\n188\nBoletim 100: Recomendações de adubação e calagem para o estado de São Paulo\nquantidades de nutrientes exportadas com a colheita de frutas cítricas. Esses valores se aplicam para pomares com produtividades de 30 a 60 t ha -1 de frutos.\nTabela 1. Conteúdo de nutrientes exportado por tonelada de fruto colhido'
# chunker.serialize(chunk) (112 tokens):
# '2. Exportação de nutrientes\n187\n188\nBoletim 100: Recomendações de adubação e calagem para o estado de São Paulo\nquantidades de nutrientes exportadas com a colheita de frutas cítricas. Esses valores se aplicam para pomares com produtividades de 30 a 60 t ha -1 de frutos.\nTabela 1. Conteúdo de nutrientes exportado por tonelada de fruto colhido'
#
# === 5 ===
# chunk.text (267 tokens):
# 'Citros, N.kg t -1 ____________________________________ = 1,9-2,4. Citros, P.kg t -1 ____________________________________ = 0,15-0,21. Citros, K.kg t -1 ____________________________________ = 1,3-2,1. Citros, Ca.kg t -1 ____________________________________ = 0,45-0,64. Citros, Mg.kg t -1 ____________________________________ ='
# chunker.serialize(chunk) (298 tokens):
# '2. Exportação de nutrientes\nTabela 1. Conteúdo de nutrientes exportado por tonelada de fruto colhido\nCitros, N.kg t -1 ____________________________________ = 1,9-2,4. Citros, P.kg t -1 ____________________________________ = 0,15-0,21. Citros, K.kg t -1 ____________________________________ = 1,3-2,1. Citros, Ca.kg t -1 ____________________________________ = 0,45-0,64. Citros, Mg.kg t -1 ____________________________________ ='
#
# === 6 ===
# chunk.text (252 tokens):
# '0,11-0,15. Citros, S.kg t -1 ____________________________________ = 0,10-0,18. , N.kg t -1 ____________________________________ = B. , P.kg t -1 ____________________________________ = Cu. , K.kg t -1 ____________________________________ = . , Ca.kg t -1 ____________________________________ = . , Mg.kg t -1'
# chunker.serialize(chunk) (283 tokens):
# '2. Exportação de nutrientes\nTabela 1. Conteúdo de nutrientes exportado por tonelada de fruto colhido\n0,11-0,15. Citros, S.kg t -1 ____________________________________ = 0,10-0,18. , N.kg t -1 ____________________________________ = B. , P.kg t -1 ____________________________________ = Cu. , K.kg t -1 ____________________________________ = . , Ca.kg t -1 ____________________________________ = . , Mg.kg t -1'
#
# === 7 ===
# chunk.text (268 tokens):
# '____________________________________ = Mn. , S.kg t -1 ____________________________________ = Zn. , N.kg t -1 ____________________________________ = Fe. , P.kg t -1 ____________________________________ = Fe. , K.kg t -1 ____________________________________ = Fe. , Ca.kg t -1 ____________________________________ ='
# chunker.serialize(chunk) (299 tokens):
# '2. Exportação de nutrientes\nTabela 1. Conteúdo de nutrientes exportado por tonelada de fruto colhido\n____________________________________ = Mn. , S.kg t -1 ____________________________________ = Zn. , N.kg t -1 ____________________________________ = Fe. , P.kg t -1 ____________________________________ = Fe. , K.kg t -1 ____________________________________ = Fe. , Ca.kg t -1 ____________________________________ ='
#
# === 8 ===
# chunk.text (269 tokens):
# 'Fe. , Mg.kg t -1 ____________________________________ = Fe. , S.kg t -1 ____________________________________ = Fe. Citros, N.kg t -1 ____________________________________ = 2,0-6,0. Citros, P.kg t -1 ____________________________________ = 0,4-0,7. Citros, K.kg t -1 ____________________________________ = 3,0-5,0. Citros, Ca.kg t -1'
# chunker.serialize(chunk) (300 tokens):
# '2. Exportação de nutrientes\nTabela 1. Conteúdo de nutrientes exportado por tonelada de fruto colhido\nFe. , Mg.kg t -1 ____________________________________ = Fe. , S.kg t -1 ____________________________________ = Fe. Citros, N.kg t -1 ____________________________________ = 2,0-6,0. Citros, P.kg t -1 ____________________________________ = 0,4-0,7. Citros, K.kg t -1 ____________________________________ = 3,0-5,0. Citros, Ca.kg t -1'
#
# === 9 ===
# chunk.text (147 tokens):
# '____________________________________ = . Citros, Mg.kg t -1 ____________________________________ = 1,0-3,0. Citros, S.kg t -1 ____________________________________ = 1,0-3,0'
# chunker.serialize(chunk) (178 tokens):
# '2. Exportação de nutrientes\nTabela 1. Conteúdo de nutrientes exportado por tonelada de fruto colhido\n____________________________________ = . Citros, Mg.kg t -1 ____________________________________ = 1,0-3,0. Citros, S.kg t -1 ____________________________________ = 1,0-3,0'
#
# === 10 ===
# chunk.text (169 tokens):
# 'Os  citros  armazenam  grande  quantidade  de  nutrientes  na biomassa  que  podem  ser  redistribuídos,  principalmente,  para  órgãos em desenvolvimento como folhas e frutos. Assim, a análise foliar é uma ferramenta útil para complementar a análise de solo e aferir o equilíbrio nutricional da planta. Além disso, para o caso do nitrogênio (N), cujos métodos de análise de solo não têm consistência no diagnóstico, o teor do nutriente  nas  folhas  é  usado  como  critério  direto  de  avaliação  da disponibilidade de N para as plantas.'
# chunker.serialize(chunk) (185 tokens):
# '3. Amostragem e análise química de folha\nOs  citros  armazenam  grande  quantidade  de  nutrientes  na biomassa  que  podem  ser  redistribuídos,  principalmente,  para  órgãos em desenvolvimento como folhas e frutos. Assim, a análise foliar é uma ferramenta útil para complementar a análise de solo e aferir o equilíbrio nutricional da planta. Além disso, para o caso do nitrogênio (N), cujos métodos de análise de solo não têm consistência no diagnóstico, o teor do nutriente  nas  folhas  é  usado  como  critério  direto  de  avaliação  da disponibilidade de N para as plantas.'
#
# === 11 ===
# chunk.text (125 tokens):
# 'Coletar a 3ª ou 4ª folha do ramo com fruto terminal, geradas na primavera, com aproximadamente seis meses de idade, normalmente de fevereiro a março, em ramos com frutos de 2 a 4 cm de diâmetro. Amostrar peloglyph<c=3,font=/CIDFont+F8>menosglyph<c=3,font=/CIDFont+F8>20glyph<c=3,font=/CIDFont+F8>ár'
# chunker.serialize(chunk) (144 tokens):
# '4. Instruções para a amostragem foliar para citros\nColetar a 3ª ou 4ª folha do ramo com fruto terminal, geradas na primavera, com aproximadamente seis meses de idade, normalmente de fevereiro a março, em ramos com frutos de 2 a 4 cm de diâmetro. Amostrar peloglyph<c=3,font=/CIDFont+F8>menosglyph<c=3,font=/CIDFont+F8>20glyph<c=3,font=/CIDFont+F8>ár'
#
# === 12 ===
# chunk.text (231 tokens):
# 'voresglyph<c=3,font=/CIDFont+F8>porglyph<c=3,font=/CIDFont+F8>talhão,glyph<c=3,font=/CIDFont+F8>coletandoglyph<c=3,font=/CIDFont+F8>quatroglyph<c=3,font=/CIDFont+F8>folhasglyph<c=3,font=/CIDFont+F8>nãoglyph<c=3,font=/CIDFont+F8>daniÀcadasglyph<c=3,font=/CIDFont+F8> por árvore, uma em cada quadrante e na altura mediana da copa.\nPulverizações  com  adubos  foliares,  e/ou  o  uso  de  defensivos contendo  nutrientes,  podem  deixar  parte  dos  elementos  aderidos  na\nB-100, 2022\nCitros'
# chunker.serialize(chunk) (250 tokens):
# '4. Instruções para a amostragem foliar para citros\nvoresglyph<c=3,font=/CIDFont+F8>porglyph<c=3,font=/CIDFont+F8>talhão,glyph<c=3,font=/CIDFont+F8>coletandoglyph<c=3,font=/CIDFont+F8>quatroglyph<c=3,font=/CIDFont+F8>folhasglyph<c=3,font=/CIDFont+F8>nãoglyph<c=3,font=/CIDFont+F8>daniÀcadasglyph<c=3,font=/CIDFont+F8> por árvore, uma em cada quadrante e na altura mediana da copa.\nPulverizações  com  adubos  foliares,  e/ou  o  uso  de  defensivos contendo  nutrientes,  podem  deixar  parte  dos  elementos  aderidos  na\nB-100, 2022\nCitros'
#
# === 13 ===
# chunk.text (206 tokens):
# 'superfície do limbo foliar por vários meses e levar ao erro de interpretação da análise; assim, quando possível, é recomendável não coletar folhas em um intervalo mínimo 30 dias após a última pulverização. As amostras devem  ser  acondicionadas  em  sacos  de  papel  e  enviadas  para  o laboratório em período inferior a dois dias após a coleta no campo.\nOs valores de concentrações de nutrientes nas folhas de citros e suas interpretações estão na tabela 2.\nTabela 2. Faixas  para  interpretação de teores de macro e micronutrientes nas folhas de citros, geradas na primavera, com seis meses de idade, de ramos com fruto terminal com 2 a 4 cm de diâmetro'
# chunker.serialize(chunk) (225 tokens):
# '4. Instruções para a amostragem foliar para citros\nsuperfície do limbo foliar por vários meses e levar ao erro de interpretação da análise; assim, quando possível, é recomendável não coletar folhas em um intervalo mínimo 30 dias após a última pulverização. As amostras devem  ser  acondicionadas  em  sacos  de  papel  e  enviadas  para  o laboratório em período inferior a dois dias após a coleta no campo.\nOs valores de concentrações de nutrientes nas folhas de citros e suas interpretações estão na tabela 2.\nTabela 2. Faixas  para  interpretação de teores de macro e micronutrientes nas folhas de citros, geradas na primavera, com seis meses de idade, de ramos com fruto terminal com 2 a 4 cm de diâmetro'
#
# === 14 ===
# chunk.text (219 tokens):
# '____________________, Baixo = g kg -1 ____________________. ____________________, Adequado = g kg -1 ____________________. ____________________, Alto = g kg -1 ____________________. <25, Baixo = . <25, Adequado = 25-30 >30. <25, Alto = N: Citros geral. <20, Baixo = . <20, Adequado = 20-24 >24. <20, Alto = N: Limões e lima ácida'
# chunker.serialize(chunk) (299 tokens):
# '4. Instruções para a amostragem foliar para citros\nTabela 2. Faixas  para  interpretação de teores de macro e micronutrientes nas folhas de citros, geradas na primavera, com seis meses de idade, de ramos com fruto terminal com 2 a 4 cm de diâmetro\n____________________, Baixo = g kg -1 ____________________. ____________________, Adequado = g kg -1 ____________________. ____________________, Alto = g kg -1 ____________________. <25, Baixo = . <25, Adequado = 25-30 >30. <25, Alto = N: Citros geral. <20, Baixo = . <20, Adequado = 20-24 >24. <20, Alto = N: Limões e lima ácida'
#
# === 15 ===
# chunk.text (214 tokens):
# 'Tahiti. <1,2, Baixo = . <1,2, Adequado = 1,2-1,6 >1,6. <1,2, Alto = P. <10, Baixo = . <10, Adequado = 10-15 >15. <10, Alto = K. <35, Baixo = . <35, Adequado = 35-50 >50. <35, Alto = Ca. <3,5, Baixo = . <3,5, Adequado = 3,5-5,0 >5,0. <3,5, Alto = Mg. S <2,0, Baixo = 2,0-3,0. S <2,0, Adequado = >3,0. S <2,0, Alto = . ___________________, Baixo = mg kg -1'
# chunker.serialize(chunk) (294 tokens):
# '4. Instruções para a amostragem foliar para citros\nTabela 2. Faixas  para  interpretação de teores de macro e micronutrientes nas folhas de citros, geradas na primavera, com seis meses de idade, de ramos com fruto terminal com 2 a 4 cm de diâmetro\nTahiti. <1,2, Baixo = . <1,2, Adequado = 1,2-1,6 >1,6. <1,2, Alto = P. <10, Baixo = . <10, Adequado = 10-15 >15. <10, Alto = K. <35, Baixo = . <35, Adequado = 35-50 >50. <35, Alto = Ca. <3,5, Baixo = . <3,5, Adequado = 3,5-5,0 >5,0. <3,5, Alto = Mg. S <2,0, Baixo = 2,0-3,0. S <2,0, Adequado = >3,0. S <2,0, Alto = . ___________________, Baixo = mg kg -1'
#
# === 16 ===
# chunk.text (219 tokens):
# '___________________. ___________________, Adequado = mg kg -1 ___________________. ___________________, Alto = mg kg -1 ___________________. B, Baixo = <50. B, Adequado = 50-150 >150. B, Alto = . <10, Baixo = 10-20. <10, Adequado = >20. <10, Alto = Cu. <50, Baixo = 50-150. <50, Adequado = >150. <50, Alto = Fe. <30, Baixo = 30-60. <30, Adequado ='
# chunker.serialize(chunk) (299 tokens):
# '4. Instruções para a amostragem foliar para citros\nTabela 2. Faixas  para  interpretação de teores de macro e micronutrientes nas folhas de citros, geradas na primavera, com seis meses de idade, de ramos com fruto terminal com 2 a 4 cm de diâmetro\n___________________. ___________________, Adequado = mg kg -1 ___________________. ___________________, Alto = mg kg -1 ___________________. B, Baixo = <50. B, Adequado = 50-150 >150. B, Alto = . <10, Baixo = 10-20. <10, Adequado = >20. <10, Alto = Cu. <50, Baixo = 50-150. <50, Adequado = >150. <50, Alto = Fe. <30, Baixo = 30-60. <30, Adequado ='
#
# === 17 ===
# chunk.text (82 tokens):
# '>60. <30, Alto = Mn. Mo <0,5, Baixo = 0,5-2,0. Mo <0,5, Adequado = >2,0. Mo <0,5, Alto = . <35, Baixo = 35-70. <35, Adequado = >70. <35, Alto = Zn'
# chunker.serialize(chunk) (162 tokens):
# '4. Instruções para a amostragem foliar para citros\nTabela 2. Faixas  para  interpretação de teores de macro e micronutrientes nas folhas de citros, geradas na primavera, com seis meses de idade, de ramos com fruto terminal com 2 a 4 cm de diâmetro\n>60. <30, Alto = Mn. Mo <0,5, Baixo = 0,5-2,0. Mo <0,5, Adequado = >2,0. Mo <0,5, Alto = . <35, Baixo = 35-70. <35, Adequado = >70. <35, Alto = Zn'
#
# === 18 ===
# chunk.text (142 tokens):
# 'Teores altos dos micronutrientes metálicos, especialmente Cu, às vezes podem ser encontrados na análise de folha sem que esta apresente sintomas  de  toxicidade,  o  que  pode  levar  à  interpretação  errônea  do estado nutricional, pois estes nutrientes podem apenas estar aderidos à superfície da folha sem exercer papel metabólico na planta.\nB-100, 2022\n189\n190\nBoletim 100: Recomendações de adubação e calagem para o estado de São Paulo'
# chunker.serialize(chunk) (161 tokens):
# '4. Instruções para a amostragem foliar para citros\nTeores altos dos micronutrientes metálicos, especialmente Cu, às vezes podem ser encontrados na análise de folha sem que esta apresente sintomas  de  toxicidade,  o  que  pode  levar  à  interpretação  errônea  do estado nutricional, pois estes nutrientes podem apenas estar aderidos à superfície da folha sem exercer papel metabólico na planta.\nB-100, 2022\n189\n190\nBoletim 100: Recomendações de adubação e calagem para o estado de São Paulo'
#
# === 19 ===
# chunk.text (230 tokens):
# 'Os teores foliares dos nutrientes não dependem unicamente da disponibilidadeglyph<c=3,font=/CIDFont+F8> doglyph<c=3,font=/CIDFont+F8> elementoglyph<c=3,font=/CIDFont+F8> noglyph<c=3,font=/CIDFont+F8> solo,glyph<c=3,font=/CIDFont+F8> poisglyph<c=3,font=/CIDFont+F8> sofremglyph<c=3,font=/CIDFont+F8> inÁuênciaglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> váriosglyph<c=3,font=/CIDFont+F8> outros  fatores  como  taxa  de  crescimento  da  planta,  idade  da'
# chunker.serialize(chunk) (249 tokens):
# '4. Instruções para a amostragem foliar para citros\nOs teores foliares dos nutrientes não dependem unicamente da disponibilidadeglyph<c=3,font=/CIDFont+F8> doglyph<c=3,font=/CIDFont+F8> elementoglyph<c=3,font=/CIDFont+F8> noglyph<c=3,font=/CIDFont+F8> solo,glyph<c=3,font=/CIDFont+F8> poisglyph<c=3,font=/CIDFont+F8> sofremglyph<c=3,font=/CIDFont+F8> inÁuênciaglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> váriosglyph<c=3,font=/CIDFont+F8> outros  fatores  como  taxa  de  crescimento  da  planta,  idade  da'
#
# === 20 ===
# chunk.text (155 tokens):
# 'folha, combinações copa e porta-enxerto, e interações com outros nutrientes. Os teores de nutrientes com alta redistribuição dentro da planta, como N, P e K, diminuem com a idade da folha, enquanto os teores de nutriente imóveis como Ca e B, por exemplo, aumentam nas folhas mais velhas. Assim, pelos motivos citados, as folhas coletadas para análise devem ser da mesma idade daquelas que foram usadas na tabela de interpretação (Tabela 2).'
# chunker.serialize(chunk) (174 tokens):
# '4. Instruções para a amostragem foliar para citros\nfolha, combinações copa e porta-enxerto, e interações com outros nutrientes. Os teores de nutrientes com alta redistribuição dentro da planta, como N, P e K, diminuem com a idade da folha, enquanto os teores de nutriente imóveis como Ca e B, por exemplo, aumentam nas folhas mais velhas. Assim, pelos motivos citados, as folhas coletadas para análise devem ser da mesma idade daquelas que foram usadas na tabela de interpretação (Tabela 2).'
#
# === 21 ===
# chunk.text (94 tokens):
# 'A  amostragem  de  solo  deve  ser  feita  em  glebas  ou  talhões homogêneos quanto à cor e textura do solo, posição no relevo e manejo do pomar, idade das árvores, combinações de copa e porta-enxerto e produtividade.\nColetar  as  amostras  nas  profundidades  de  0-20  cm  para'
# chunker.serialize(chunk) (106 tokens):
# '5. Amostragem de solo em pomares\nA  amostragem  de  solo  deve  ser  feita  em  glebas  ou  talhões homogêneos quanto à cor e textura do solo, posição no relevo e manejo do pomar, idade das árvores, combinações de copa e porta-enxerto e produtividade.\nColetar  as  amostras  nas  profundidades  de  0-20  cm  para'
#
# === 22 ===
# chunk.text (275 tokens):
# 'as recomendações de adubação e a calagem. Coletar solo na camada de 20-40 cm para o diagnóstico de barreiras químicas ao desenvolvimento dasglyph<c=3,font=/CIDFont+F8> raízes,glyph<c=3,font=/CIDFont+F8> ouglyph<c=3,font=/CIDFont+F8> seja,glyph<c=3,font=/CIDFont+F8> deÀciênciasglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> Caglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> ouglyph<c=3,font=/CIDFont+F8> excessoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> alumínio,glyph<c=3,font=/CIDFont+F8>'
# chunker.serialize(chunk) (287 tokens):
# '5. Amostragem de solo em pomares\nas recomendações de adubação e a calagem. Coletar solo na camada de 20-40 cm para o diagnóstico de barreiras químicas ao desenvolvimento dasglyph<c=3,font=/CIDFont+F8> raízes,glyph<c=3,font=/CIDFont+F8> ouglyph<c=3,font=/CIDFont+F8> seja,glyph<c=3,font=/CIDFont+F8> deÀciênciasglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> Caglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> ouglyph<c=3,font=/CIDFont+F8> excessoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> alumínio,glyph<c=3,font=/CIDFont+F8>'
#
# === 23 ===
# chunk.text (237 tokens):
# 'comoglyph<c=3,font=/CIDFont+F8> também\npara  aferir  movimentação  ou  perda  de  nutrientes  abaixo da  camada  com  maior  concentração  de  raízes.  Coletar  de  15  a  20 subamostras por talhão, com trados do tipo holandês ou sonda.\nAntes da implantação do pomar, coletar o solo nas profundidades de 0-0 cm e 20-40 cm percorrendo a área em zigue-zague. Após o plantio, em pomares não irrigados, amostrar na faixa de adubação, sendo uma subamostra coletada cerca de 50 cm para dentro e outra 50 cm para fora da projeção da copa das árvores. Para pomares fertirrigados, amostrar dentro do bulbo úmido, de 20 cm a 30 cm da linha de gotejo em direção oposta ao tronco da árvore.'
# chunker.serialize(chunk) (249 tokens):
# '5. Amostragem de solo em pomares\ncomoglyph<c=3,font=/CIDFont+F8> também\npara  aferir  movimentação  ou  perda  de  nutrientes  abaixo da  camada  com  maior  concentração  de  raízes.  Coletar  de  15  a  20 subamostras por talhão, com trados do tipo holandês ou sonda.\nAntes da implantação do pomar, coletar o solo nas profundidades de 0-0 cm e 20-40 cm percorrendo a área em zigue-zague. Após o plantio, em pomares não irrigados, amostrar na faixa de adubação, sendo uma subamostra coletada cerca de 50 cm para dentro e outra 50 cm para fora da projeção da copa das árvores. Para pomares fertirrigados, amostrar dentro do bulbo úmido, de 20 cm a 30 cm da linha de gotejo em direção oposta ao tronco da árvore.'
#
# === 24 ===
# chunk.text (97 tokens):
# 'Amostrar o solo anualmente na camada de 0-20 cm e a cada dois anos na camada de 20-40 cm. Coletar as amostras após 2/3 da adubação anual ter sido realizada, mantendo um intervalo mínimo de 30 a 45 dias após o último parcelamento da adubação sólida.\nB-100, 2022\nCitros'
# chunker.serialize(chunk) (109 tokens):
# '5. Amostragem de solo em pomares\nAmostrar o solo anualmente na camada de 0-20 cm e a cada dois anos na camada de 20-40 cm. Coletar as amostras após 2/3 da adubação anual ter sido realizada, mantendo um intervalo mínimo de 30 a 45 dias após o último parcelamento da adubação sólida.\nB-100, 2022\nCitros'
#
# === 25 ===
# chunk.text (144 tokens):
# 'Introdução: As recomendações para o manejo da fertilidade do solo na citricultura paulista contemplam todo avanço obtido nas últimas duas décadas de pesquisa no Brasil. Os novos conhecimentos certamente vêm contribuindo para o grande salto em produtividade da citricultura paulista nos últimos anos, que passou de 10 t ha -1 em 1980 para 40 t ha -1 em 2020, sendo que os melhores pomares alcançam médias acima de 50 t ha -1 .'
# chunker.serialize(chunk) (164 tokens):
# '6. Recomendações de adubação e calagem para os citros\nIntrodução: As recomendações para o manejo da fertilidade do solo na citricultura paulista contemplam todo avanço obtido nas últimas duas décadas de pesquisa no Brasil. Os novos conhecimentos certamente vêm contribuindo para o grande salto em produtividade da citricultura paulista nos últimos anos, que passou de 10 t ha -1 em 1980 para 40 t ha -1 em 2020, sendo que os melhores pomares alcançam médias acima de 50 t ha -1 .'
#
# === 26 ===
# chunk.text (244 tokens):
# 'Os citros têm algumas particularidades e demandas nutricionais diferenciadas,  como  o  fato  do  cálcio  ser  o  nutriente  em  maiores concentrações  nas  folhas  em  comparação  com  outras  culturas. Espécies e porta-enxertos também têm demandas diferenciadas. Entre os  avanços  recentes  destacam-se  os  ajustes  nas  recomendações  de nutrientes dos novos porta-enxertos que substituíram o limão-cravo; as novas informações sobre a resposta e o manejo de micronutrientes em citros  e  o  preparo  reduzido  solo,  com  plantio  das  mudas  em  faixas  e incorporação profunda de calcário e fósforo no sulco de plantio, o que proporciona  desenvolvimento  mais  rápido  das  mudas,  produtividade mais  precoce  e  boa  conservação  do  solo.  Outro  fator  importante'
# chunker.serialize(chunk) (264 tokens):
# '6. Recomendações de adubação e calagem para os citros\nOs citros têm algumas particularidades e demandas nutricionais diferenciadas,  como  o  fato  do  cálcio  ser  o  nutriente  em  maiores concentrações  nas  folhas  em  comparação  com  outras  culturas. Espécies e porta-enxertos também têm demandas diferenciadas. Entre os  avanços  recentes  destacam-se  os  ajustes  nas  recomendações  de nutrientes dos novos porta-enxertos que substituíram o limão-cravo; as novas informações sobre a resposta e o manejo de micronutrientes em citros  e  o  preparo  reduzido  solo,  com  plantio  das  mudas  em  faixas  e incorporação profunda de calcário e fósforo no sulco de plantio, o que proporciona  desenvolvimento  mais  rápido  das  mudas,  produtividade mais  precoce  e  boa  conservação  do  solo.  Outro  fator  importante'
#
# === 27 ===
# chunk.text (222 tokens):
# 'no ganho de produtividade da citricultura foi o adensamento de plantio, associado com irrigação e fertirrigação, que tem permitido aumentos de 20%glyph<c=3,font=/CIDFont+F8>aglyph<c=3,font=/CIDFont+F8>25%glyph<c=3,font=/CIDFont+F8>naglyph<c=3,font=/CIDFont+F8>eÀciênciaglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>usoglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>nutrientes.glyph<c=3,font=/CIDFont+F8>'
# chunker.serialize(chunk) (242 tokens):
# '6. Recomendações de adubação e calagem para os citros\nno ganho de produtividade da citricultura foi o adensamento de plantio, associado com irrigação e fertirrigação, que tem permitido aumentos de 20%glyph<c=3,font=/CIDFont+F8>aglyph<c=3,font=/CIDFont+F8>25%glyph<c=3,font=/CIDFont+F8>naglyph<c=3,font=/CIDFont+F8>eÀciênciaglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>usoglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>nutrientes.glyph<c=3,font=/CIDFont+F8>'
#
# === 28 ===
# chunk.text (265 tokens):
# 'A presente tabela de recomendações leva em conta exigências de espécies e porta-enxertos, e também das características de frutas para diferentes mercados. Por exemplo, o mercado de frutas frescas requer frutosglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> maiorglyph<c=3,font=/CIDFont+F8> tamanhoglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> cascaglyph<c=3,font=/CIDFont+F8> Àrme;glyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> indústriaglyph<c=3,font=/CIDFont+F8>'
# chunker.serialize(chunk) (285 tokens):
# '6. Recomendações de adubação e calagem para os citros\nA presente tabela de recomendações leva em conta exigências de espécies e porta-enxertos, e também das características de frutas para diferentes mercados. Por exemplo, o mercado de frutas frescas requer frutosglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> maiorglyph<c=3,font=/CIDFont+F8> tamanhoglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> cascaglyph<c=3,font=/CIDFont+F8> Àrme;glyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> indústriaglyph<c=3,font=/CIDFont+F8>'
#
# === 29 ===
# chunk.text (269 tokens):
# 'deglyph<c=3,font=/CIDFont+F8> sucos,glyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> adubação visa otimazar a produtividade por área.\nEspaçamento: O  adensamento  de  plantio  na  citricultura aumentou nos últimos anos devido principalmente à incidência do HLB ou greening ,  cujo  manejo pode levar à erradicação de grande número de plantas anualmente. Desta maneira, o espaçamento de plantio está sendo reduzido com o objetivo de mitigar as perdas de plantas ao longo da vida útil dos talhões. Atualmente, os espaçamentos recomendados entrelinhas de plantio variam de 6 m a 7 m, enquanto os entre plantas variam de 2 m a 3 m.\nB-100, 2022\n191\n192\nBoletim 100: Recomendações de adubação e calagem para o estado de São Paulo'
# chunker.serialize(chunk) (289 tokens):
# '6. Recomendações de adubação e calagem para os citros\ndeglyph<c=3,font=/CIDFont+F8> sucos,glyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> adubação visa otimazar a produtividade por área.\nEspaçamento: O  adensamento  de  plantio  na  citricultura aumentou nos últimos anos devido principalmente à incidência do HLB ou greening ,  cujo  manejo pode levar à erradicação de grande número de plantas anualmente. Desta maneira, o espaçamento de plantio está sendo reduzido com o objetivo de mitigar as perdas de plantas ao longo da vida útil dos talhões. Atualmente, os espaçamentos recomendados entrelinhas de plantio variam de 6 m a 7 m, enquanto os entre plantas variam de 2 m a 3 m.\nB-100, 2022\n191\n192\nBoletim 100: Recomendações de adubação e calagem para o estado de São Paulo'
#
# === 30 ===
# chunk.text (233 tokens):
# 'Calagem: Os citros são exigentes em cálcio e produzem melhor em  solos  próximos  da  neutralidade.  A  calagem  no  plantio  merece atenção especial, pois esta é a melhor oportunidade para a incorporação do  calcário  e  para  corrigir  a  acidez  nas  camadas  mais  profundas  do solo. Antes da implantação do pomar, o calcário deve ser aplicado na faixa de plantio das mudas, com largura ao redor de 2 m, e incorporado com grade pesada o mais profundamente possível. Aplicar calcário para elevar  a  saturação  por  bases (V)  a  70%  e  manter  o  teor  de  magnésio em pelo menos 8 mmol c dm -3 na camada de 0-20 cm de profundidade. Caso  a  saturação  por  bases  da  camada  de  20-40  cm  seja  inferior'
# chunker.serialize(chunk) (253 tokens):
# '6. Recomendações de adubação e calagem para os citros\nCalagem: Os citros são exigentes em cálcio e produzem melhor em  solos  próximos  da  neutralidade.  A  calagem  no  plantio  merece atenção especial, pois esta é a melhor oportunidade para a incorporação do  calcário  e  para  corrigir  a  acidez  nas  camadas  mais  profundas  do solo. Antes da implantação do pomar, o calcário deve ser aplicado na faixa de plantio das mudas, com largura ao redor de 2 m, e incorporado com grade pesada o mais profundamente possível. Aplicar calcário para elevar  a  saturação  por  bases (V)  a  70%  e  manter  o  teor  de  magnésio em pelo menos 8 mmol c dm -3 na camada de 0-20 cm de profundidade. Caso  a  saturação  por  bases  da  camada  de  20-40  cm  seja  inferior'
#
# === 31 ===
# chunk.text (224 tokens):
# 'a 25%, aumentar em 50% a dose de calcário aplicado nesta faixa. Além da calagem na faixa, uma dose adicional de calcário deve ser aplicada também no sulco de plantio, à taxa de 0,5 kg ha -1 por metro de sulco, e posteriormente misturado ao solo até a profundidade de 25 cm a 30 cm com subsolador de três hastes, o qual também realiza a incorporação do fósforo em profundidade, como descrito adiante. O restante da área dos  talhões,  ou  seja,  o  meio  das  ruas,  deverá  receber  a  mesma  dose de  calcário,  em  t  ha -1 ,  recomendada  para  a  faixa  de  plantio,  porém  a incorporação deverá ser feita em ruas alternadas para a maior proteção do solo contra a erosão.'
# chunker.serialize(chunk) (244 tokens):
# '6. Recomendações de adubação e calagem para os citros\na 25%, aumentar em 50% a dose de calcário aplicado nesta faixa. Além da calagem na faixa, uma dose adicional de calcário deve ser aplicada também no sulco de plantio, à taxa de 0,5 kg ha -1 por metro de sulco, e posteriormente misturado ao solo até a profundidade de 25 cm a 30 cm com subsolador de três hastes, o qual também realiza a incorporação do fósforo em profundidade, como descrito adiante. O restante da área dos  talhões,  ou  seja,  o  meio  das  ruas,  deverá  receber  a  mesma  dose de  calcário,  em  t  ha -1 ,  recomendada  para  a  faixa  de  plantio,  porém  a incorporação deverá ser feita em ruas alternadas para a maior proteção do solo contra a erosão.'
#
# === 32 ===
# chunk.text (70 tokens):
# 'Em pomares já plantados, cerca de 70% da dose de calcário deve ser aplicada sob a projeção das copas das plantas e o restante na rua. Em pomares fertirrigados, toda a dose deve ser aplicada sob a projeção da'
# chunker.serialize(chunk) (90 tokens):
# '6. Recomendações de adubação e calagem para os citros\nEm pomares já plantados, cerca de 70% da dose de calcário deve ser aplicada sob a projeção das copas das plantas e o restante na rua. Em pomares fertirrigados, toda a dose deve ser aplicada sob a projeção da'
#
# === 33 ===
# chunk.text (212 tokens):
# 'copa,glyph<c=3,font=/CIDFont+F8>devidoglyph<c=3,font=/CIDFont+F8>àglyph<c=3,font=/CIDFont+F8>acidiÀcaçãoglyph<c=3,font=/CIDFont+F8>doglyph<c=3,font=/CIDFont+F8>sologlyph<c=3,font=/CIDFont+F8>serglyph<c=3,font=/CIDFont+F8>maisglyph<c=3,font=/CIDFont+F8>intensaglyph<c=3,font=/CIDFont+F8>nestaglyph<c=3,font=/CIDFont+F8>região.glyph<c=3,font=/CIDFont+F8>'
# chunker.serialize(chunk) (232 tokens):
# '6. Recomendações de adubação e calagem para os citros\ncopa,glyph<c=3,font=/CIDFont+F8>devidoglyph<c=3,font=/CIDFont+F8>àglyph<c=3,font=/CIDFont+F8>acidiÀcaçãoglyph<c=3,font=/CIDFont+F8>doglyph<c=3,font=/CIDFont+F8>sologlyph<c=3,font=/CIDFont+F8>serglyph<c=3,font=/CIDFont+F8>maisglyph<c=3,font=/CIDFont+F8>intensaglyph<c=3,font=/CIDFont+F8>nestaglyph<c=3,font=/CIDFont+F8>região.glyph<c=3,font=/CIDFont+F8>'
#
# === 34 ===
# chunk.text (154 tokens):
# 'Gessagem: Em pomares instalados, da mesma forma que o calcário, o gesso deve ser distribuído de forma localizada na faixa de adubação, quando os teores foliares de cálcio forem menores que 35 g kg -1 . Assim, aplicar 1,0, 1,5 ou 2,0 t ha -1 de gesso, respectivamente, para solos arenosos (<200 g kg -1 de  argila),  de  textura  média  (200-400  g  kg -1 de  argila)  ou argilosos (>400 g kg -1 de argila).'
# chunker.serialize(chunk) (174 tokens):
# '6. Recomendações de adubação e calagem para os citros\nGessagem: Em pomares instalados, da mesma forma que o calcário, o gesso deve ser distribuído de forma localizada na faixa de adubação, quando os teores foliares de cálcio forem menores que 35 g kg -1 . Assim, aplicar 1,0, 1,5 ou 2,0 t ha -1 de gesso, respectivamente, para solos arenosos (<200 g kg -1 de  argila),  de  textura  média  (200-400  g  kg -1 de  argila)  ou argilosos (>400 g kg -1 de argila).'
#
# === 35 ===
# chunk.text (251 tokens):
# 'Adubação de sulco de plantio: Aplicar 90 g de P 2 O 5 por metro de sulco, que de acordo com o espaçamento varia de 120 a 160 kg ha -1 de P 2 O 5 . A experiência de vários anos somada aos resultados de pesquisas tem demonstrado as vantagens da adubação desta aplicação extra de P em profundidade no sulco de plantio após a calagem. O citricultor deve dar preferência a fontes de fosfatos solúveis em água, e se possível, contendo zinco. Esta é a única oportunidade para aplicar P em profundidade. Para\nB-100, 2022\nCitros\nfacilitar a incorporação de calcário no sulco e simultaneamente aplicar P em profundidade, um subsolador triplo, dotado de dispositivo capaz de aplicar P junto das suas hastes, pode ser utilizado.'
# chunker.serialize(chunk) (271 tokens):
# '6. Recomendações de adubação e calagem para os citros\nAdubação de sulco de plantio: Aplicar 90 g de P 2 O 5 por metro de sulco, que de acordo com o espaçamento varia de 120 a 160 kg ha -1 de P 2 O 5 . A experiência de vários anos somada aos resultados de pesquisas tem demonstrado as vantagens da adubação desta aplicação extra de P em profundidade no sulco de plantio após a calagem. O citricultor deve dar preferência a fontes de fosfatos solúveis em água, e se possível, contendo zinco. Esta é a única oportunidade para aplicar P em profundidade. Para\nB-100, 2022\nCitros\nfacilitar a incorporação de calcário no sulco e simultaneamente aplicar P em profundidade, um subsolador triplo, dotado de dispositivo capaz de aplicar P junto das suas hastes, pode ser utilizado.'
#
# === 36 ===
# chunk.text (273 tokens):
# 'Adubaçãoglyph<c=3,font=/CIDFont+F5> deglyph<c=3,font=/CIDFont+F5> formação: Durante a fase de formação do pomar, até o quarto ano, as doses de N, P 2 O 5 e  K 2 O recomendadas levam em conta  a  idade  do  pomar  e  os  resultados  da  análise  de  solo  para  P  e K para atender às necessidades de crescimento da copa e o início de produção de frutos (Tabela 3). Ajustes nas doses recomendadas de P e K devem ser feitos levando em conta o porta-enxerto plantado. As doses de N e K devem ser parceladas de 4 a 6 vezes, entre setembro a março. Maior número de parcelamentos é necessário nos primeiros anos após o plantio das mudas. A aplicação de P deve ser preferencialmente em dose única, antes do primeiro parcelamento de N e K, geralmente entre os meses de julho a agosto.'
# chunker.serialize(chunk) (293 tokens):
# '6. Recomendações de adubação e calagem para os citros\nAdubaçãoglyph<c=3,font=/CIDFont+F5> deglyph<c=3,font=/CIDFont+F5> formação: Durante a fase de formação do pomar, até o quarto ano, as doses de N, P 2 O 5 e  K 2 O recomendadas levam em conta  a  idade  do  pomar  e  os  resultados  da  análise  de  solo  para  P  e K para atender às necessidades de crescimento da copa e o início de produção de frutos (Tabela 3). Ajustes nas doses recomendadas de P e K devem ser feitos levando em conta o porta-enxerto plantado. As doses de N e K devem ser parceladas de 4 a 6 vezes, entre setembro a março. Maior número de parcelamentos é necessário nos primeiros anos após o plantio das mudas. A aplicação de P deve ser preferencialmente em dose única, antes do primeiro parcelamento de N e K, geralmente entre os meses de julho a agosto.'
#
# === 37 ===
# chunk.text (280 tokens):
# 'No  passado,  as  recomendações  de  nutrientes  para  o  período de formação dos citros eram feitas para plantas até a idade de 4 a 5 anos.  Entretanto,  o  aumento  da  densidade  de  plantio  e  plantas  mais próximasglyph<c=3,font=/CIDFont+F8> entreglyph<c=3,font=/CIDFont+F8> si,glyph<c=3,font=/CIDFont+F8> permitiuglyph<c=3,font=/CIDFont+F8> ganhosglyph<c=3,font=/CIDFont+F8> naglyph<c=3,font=/CIDFont+F8> eÀciênciaglyph<c=3,font=/CIDFont+F8> fer tilizante.glyph<c=3,font=/CIDFont+F8> Alémglyph<c=3,font=/CIDFont+F8> disso,glyph<c=3,font=/CIDFont+F8> com  o  adensamento  de  plantio,  o  antigo  cálculo  de'
# chunker.serialize(chunk) (300 tokens):
# '6. Recomendações de adubação e calagem para os citros\nNo  passado,  as  recomendações  de  nutrientes  para  o  período de formação dos citros eram feitas para plantas até a idade de 4 a 5 anos.  Entretanto,  o  aumento  da  densidade  de  plantio  e  plantas  mais próximasglyph<c=3,font=/CIDFont+F8> entreglyph<c=3,font=/CIDFont+F8> si,glyph<c=3,font=/CIDFont+F8> permitiuglyph<c=3,font=/CIDFont+F8> ganhosglyph<c=3,font=/CIDFont+F8> naglyph<c=3,font=/CIDFont+F8> eÀciênciaglyph<c=3,font=/CIDFont+F8> fer tilizante.glyph<c=3,font=/CIDFont+F8> Alémglyph<c=3,font=/CIDFont+F8> disso,glyph<c=3,font=/CIDFont+F8> com  o  adensamento  de  plantio,  o  antigo  cálculo  de'
#
# === 38 ===
# chunk.text (117 tokens):
# 'dose  de  adubo por planta resultava em doses por área muito elevadas, o que gerava plantas  excessivamente  vigorosas.  Para  superar  esses  problemas,  as recomendações  atuais  para  a  formação  dos  citros  são  calculadas  por área, conforme a tabela abaixo.\nTabela 3. Recomendações de adubação para citros em formação, em função da idade da planta e da análise do solo (1)'
# chunker.serialize(chunk) (137 tokens):
# '6. Recomendações de adubação e calagem para os citros\ndose  de  adubo por planta resultava em doses por área muito elevadas, o que gerava plantas  excessivamente  vigorosas.  Para  superar  esses  problemas,  as recomendações  atuais  para  a  formação  dos  citros  são  calculadas  por área, conforme a tabela abaixo.\nTabela 3. Recomendações de adubação para citros em formação, em função da idade da planta e da análise do solo (1)'
#
# === 39 ===
# chunk.text (229 tokens):
# 'Anos, N. = kg ha -1  de N. Anos, P resina, mg dm -3.<16 = ______  kg ha -1  de P 2 O 5 ______. Anos, P resina, mg dm -3.16-40 = ______  kg ha -1  de P 2 O 5 ______. Anos, P resina, mg dm -3.>40 = ______  kg ha -1  de P 2 O 5 ______. Anos, K +  trocável, mmol c  dm -3.<1,6 = ______  kg ha -1  de K 2 O  ______. Anos, K +  trocável, mmol c  dm -3.1,6-3,0 = ______  kg ha -1  de K 2 O  ______. Anos, K +  trocável, mmol c'
# chunker.serialize(chunk) (289 tokens):
# '6. Recomendações de adubação e calagem para os citros\nTabela 3. Recomendações de adubação para citros em formação, em função da idade da planta e da análise do solo (1)\nAnos, N. = kg ha -1  de N. Anos, P resina, mg dm -3.<16 = ______  kg ha -1  de P 2 O 5 ______. Anos, P resina, mg dm -3.16-40 = ______  kg ha -1  de P 2 O 5 ______. Anos, P resina, mg dm -3.>40 = ______  kg ha -1  de P 2 O 5 ______. Anos, K +  trocável, mmol c  dm -3.<1,6 = ______  kg ha -1  de K 2 O  ______. Anos, K +  trocável, mmol c  dm -3.1,6-3,0 = ______  kg ha -1  de K 2 O  ______. Anos, K +  trocável, mmol c'
#
# === 40 ===
# chunk.text (164 tokens):
# 'dm -3.>3,0 = ______  kg ha -1  de K 2 O  ______. 0-1, N. = 70. 0-1, P resina, mg dm -3.<16 = 15. 0-1, P resina, mg dm -3.16-40 = 15. 0-1, P resina, mg dm -3.>40 = 15. 0-1, K +  trocável, mmol c  dm -3.<1,6 = 15. 0-1, K +  trocável, mmol c  dm -3.1,6-3,0 = 10. 0-1, K +  trocável, mmol c'
# chunker.serialize(chunk) (224 tokens):
# '6. Recomendações de adubação e calagem para os citros\nTabela 3. Recomendações de adubação para citros em formação, em função da idade da planta e da análise do solo (1)\ndm -3.>3,0 = ______  kg ha -1  de K 2 O  ______. 0-1, N. = 70. 0-1, P resina, mg dm -3.<16 = 15. 0-1, P resina, mg dm -3.16-40 = 15. 0-1, P resina, mg dm -3.>40 = 15. 0-1, K +  trocável, mmol c  dm -3.<1,6 = 15. 0-1, K +  trocável, mmol c  dm -3.1,6-3,0 = 10. 0-1, K +  trocável, mmol c'
#
# === 41 ===
# chunk.text (237 tokens):
# 'dm -3.>3,0 = 0. 1-2, N. = 100. 1-2, P resina, mg dm -3.<16 = 60. 1-2, P resina, mg dm -3.16-40 = 45. 1-2, P resina, mg dm -3.>40 = 30. 1-2, K +  trocável, mmol c  dm -3.<1,6 = 50. 1-2, K +  trocável, mmol c  dm -3.1,6-3,0 = 30. 1-2, K +  trocável, mmol c  dm -3.>3,0 = 10. 2-3, N. = 140. 2-3, P resina, mg dm -3.<16 = 90. 2-3, P resina, mg dm -3.16-40 = 60. 2-3, P resina, mg dm -3.>40 = 45. 2-3, K +  trocável, mmol c'
# chunker.serialize(chunk) (297 tokens):
# '6. Recomendações de adubação e calagem para os citros\nTabela 3. Recomendações de adubação para citros em formação, em função da idade da planta e da análise do solo (1)\ndm -3.>3,0 = 0. 1-2, N. = 100. 1-2, P resina, mg dm -3.<16 = 60. 1-2, P resina, mg dm -3.16-40 = 45. 1-2, P resina, mg dm -3.>40 = 30. 1-2, K +  trocável, mmol c  dm -3.<1,6 = 50. 1-2, K +  trocável, mmol c  dm -3.1,6-3,0 = 30. 1-2, K +  trocável, mmol c  dm -3.>3,0 = 10. 2-3, N. = 140. 2-3, P resina, mg dm -3.<16 = 90. 2-3, P resina, mg dm -3.16-40 = 60. 2-3, P resina, mg dm -3.>40 = 45. 2-3, K +  trocável, mmol c'
#
# === 42 ===
# chunk.text (209 tokens):
# 'dm -3.<1,6 = 90. 2-3, K +  trocável, mmol c  dm -3.1,6-3,0 = 60. 2-3, K +  trocável, mmol c  dm -3.>3,0 = 40. 3-4, N. = 180. 3-4, P resina, mg dm -3.<16 = 120. 3-4, P resina, mg dm -3.16-40 = 90. 3-4, P resina, mg dm -3.>40 = 60. 3-4, K +  trocável, mmol c  dm -3.<1,6 = 120. 3-4, K +  trocável, mmol c  dm -3.1,6-3,0 = 90. 3-4, K +  trocável, mmol c  dm -3.>3,0 = 60'
# chunker.serialize(chunk) (269 tokens):
# '6. Recomendações de adubação e calagem para os citros\nTabela 3. Recomendações de adubação para citros em formação, em função da idade da planta e da análise do solo (1)\ndm -3.<1,6 = 90. 2-3, K +  trocável, mmol c  dm -3.1,6-3,0 = 60. 2-3, K +  trocável, mmol c  dm -3.>3,0 = 40. 3-4, N. = 180. 3-4, P resina, mg dm -3.<16 = 120. 3-4, P resina, mg dm -3.16-40 = 90. 3-4, P resina, mg dm -3.>40 = 60. 3-4, K +  trocável, mmol c  dm -3.<1,6 = 120. 3-4, K +  trocável, mmol c  dm -3.1,6-3,0 = 90. 3-4, K +  trocável, mmol c  dm -3.>3,0 = 60'
#
# === 43 ===
# chunk.text (271 tokens):
# '(1) Para copas sobre tangerinas Cleópatra e Sunki, aumentar a dose de P 2 O 5 em 20%; para copas sobre citrumelo Swingle aumentar a dose de K 2 O em 20%.\nB-100, 2022\n193\n194\nBoletim 100: Recomendações de adubação e calagem para o estado de São Paulo\nAdubação de produção: A adubação para pomares em produção leva  em  conta,  além  da  disponibilidade  de  nutrientes  no  solo,  os teores foliares de N e a produtividade esperada. Foram estabelecidas recomendações da adubação N, P e K para os grupos de variedades de laranjas, considerando a qualidade e o destino da fruta, que pode ser para a indústria (Tabela 4) ou para o mercado in natura (Tabela 5). A tabela 5 também deve ser utilizada para as tangerinas e o Tangor Murcott, os quais possuem demandas por nutrientes semelhantes às das laranjas'
# chunker.serialize(chunk) (291 tokens):
# '6. Recomendações de adubação e calagem para os citros\n(1) Para copas sobre tangerinas Cleópatra e Sunki, aumentar a dose de P 2 O 5 em 20%; para copas sobre citrumelo Swingle aumentar a dose de K 2 O em 20%.\nB-100, 2022\n193\n194\nBoletim 100: Recomendações de adubação e calagem para o estado de São Paulo\nAdubação de produção: A adubação para pomares em produção leva  em  conta,  além  da  disponibilidade  de  nutrientes  no  solo,  os teores foliares de N e a produtividade esperada. Foram estabelecidas recomendações da adubação N, P e K para os grupos de variedades de laranjas, considerando a qualidade e o destino da fruta, que pode ser para a indústria (Tabela 4) ou para o mercado in natura (Tabela 5). A tabela 5 também deve ser utilizada para as tangerinas e o Tangor Murcott, os quais possuem demandas por nutrientes semelhantes às das laranjas'
#
# === 44 ===
# chunk.text (271 tokens):
# 'para consumo in natura. A lima ácida Tahiti e os limões verdadeiros têm recomendações distintas e para estes, a tabela 6 deve serglyph<c=3,font=/CIDFont+F8> utilizada.glyph<c=3,font=/CIDFont+F8>Aglyph<c=3,font=/CIDFont+F8> limaglyph<c=3,font=/CIDFont+F8> ácidaglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> osglyph<c=3,font=/CIDFont+F8> limõesglyph<c=3,font=/CIDFont+F8> sãoglyph<c=3,font=/CIDFont+F8> maisglyph<c=3,font=/CIDFont+F8> eÀcientesglyph<c=3,font=/CIDFont+F8> noglyph<c=3,font=/CIDFont+F8>'
# chunker.serialize(chunk) (291 tokens):
# ...
#
# === 97 ===
# chunk.text (249 tokens):
# 'Mn e Zn, deve ser praticada somente como complemento à\nadubação  via  solo,  geralmente  em  pomares  em  formação,  pois  a eÀciênciaglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>usoglyph<c=3,font=/CIDFont+F8>desseglyph<c=3,font=/CIDFont+F8>nutrienteglyph<c=3,font=/CIDFont+F8>églyph<c=3,font=/CIDFont+F8>bemglyph<c=3,font=/CIDFont+F8>maiorglyph<c=3,font=/CIDFont+F8>quandoglyph<c=3,font=/CIDFont+F8>aplicadoglyph<c=3,font=/CIDFont+F8>noglyph<c=3,font=/CIDFont+F8>solo.'
# chunker.serialize(chunk) (269 tokens):
# '6. Recomendações de adubação e calagem para os citros\nMn e Zn, deve ser praticada somente como complemento à\nadubação  via  solo,  geralmente  em  pomares  em  formação,  pois  a eÀciênciaglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>usoglyph<c=3,font=/CIDFont+F8>desseglyph<c=3,font=/CIDFont+F8>nutrienteglyph<c=3,font=/CIDFont+F8>églyph<c=3,font=/CIDFont+F8>bemglyph<c=3,font=/CIDFont+F8>maiorglyph<c=3,font=/CIDFont+F8>quandoglyph<c=3,font=/CIDFont+F8>aplicadoglyph<c=3,font=/CIDFont+F8>noglyph<c=3,font=/CIDFont+F8>solo.'
#
# === 98 ===
# chunk.text (67 tokens):
# 'A  aplicação  de  B  deve  ser  feita  preferencialmente  via  solo, parcelado  em  2  ou  3  vezes,  na  forma  de  ácido  bórico  dissolvido  na solução  de  herbicidas  de  contato,  como  o  glifosato,  que  constitui'
# chunker.serialize(chunk) (87 tokens):
# '6. Recomendações de adubação e calagem para os citros\nA  aplicação  de  B  deve  ser  feita  preferencialmente  via  solo, parcelado  em  2  ou  3  vezes,  na  forma  de  ácido  bórico  dissolvido  na solução  de  herbicidas  de  contato,  como  o  glifosato,  que  constitui'
#
# === 99 ===
# chunk.text (272 tokens):
# 'a formaglyph<c=3,font=/CIDFont+F8>maisglyph<c=3,font=/CIDFont+F8>práticaglyph<c=3,font=/CIDFont+F8>eglyph<c=3,font=/CIDFont+F8>eÀcienteglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>aplicaçãoglyph<c=3,font=/CIDFont+F8>doglyph<c=3,font=/CIDFont+F8>nutriente.glyph<c=3,font=/CIDFont+F8>Geralmenteglyph<c=3,font=/CIDFont+F8>sãoglyph<c=3,font=/CIDFont+F8> feitas de 2 a 3 aplicações de herbicidas por ano, com o volume de calda de cerca de 200 L ha -1 de área tratada, na qual a dose de 1 kg ha -1 de B (6 kg ha -1 de'
# chunker.serialize(chunk) (292 tokens):
# '6. Recomendações de adubação e calagem para os citros\na formaglyph<c=3,font=/CIDFont+F8>maisglyph<c=3,font=/CIDFont+F8>práticaglyph<c=3,font=/CIDFont+F8>eglyph<c=3,font=/CIDFont+F8>eÀcienteglyph<c=3,font=/CIDFont+F8>deglyph<c=3,font=/CIDFont+F8>aplicaçãoglyph<c=3,font=/CIDFont+F8>doglyph<c=3,font=/CIDFont+F8>nutriente.glyph<c=3,font=/CIDFont+F8>Geralmenteglyph<c=3,font=/CIDFont+F8>sãoglyph<c=3,font=/CIDFont+F8> feitas de 2 a 3 aplicações de herbicidas por ano, com o volume de calda de cerca de 200 L ha -1 de área tratada, na qual a dose de 1 kg ha -1 de B (6 kg ha -1 de'
#
# === 100 ===
# chunk.text (134 tokens):
# 'ácido bórico) é facilmente dissolvida. Aplicar 2 kg ha -1\nB-100, 2022\nCitros\nde B,  independentemente da idade do pomar, com maior número de parcelamentos em pomares recém-plantados. Quando o solo possuir teor de B abaixo de 0,6 mg dm -3 ou o porta-enxerto for o citrumelo Swingle, que é mais exigente em B, aumentar a dose anual para 3 kg ha -1 de B.'
# chunker.serialize(chunk) (154 tokens):
# '6. Recomendações de adubação e calagem para os citros\nácido bórico) é facilmente dissolvida. Aplicar 2 kg ha -1\nB-100, 2022\nCitros\nde B,  independentemente da idade do pomar, com maior número de parcelamentos em pomares recém-plantados. Quando o solo possuir teor de B abaixo de 0,6 mg dm -3 ou o porta-enxerto for o citrumelo Swingle, que é mais exigente em B, aumentar a dose anual para 3 kg ha -1 de B.'
#
# === 101 ===
# chunk.text (263 tokens):
# 'As fontes mais recomendadas de micronutrientes metálicos para aplicação foliar são sais solúveis formados com íons sulfato, cloreto ou nitrato. Para o Cu, a mistura de sulfato e hidróxido tem sido a forma mais eÀcienteglyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> fornecerglyph<c=3,font=/CIDFont+F8> oglyph<c=3,font=/CIDFont+F8> nutrienteglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> evitarglyph<c=3,font=/CIDFont+F8> Àtoxicidadeglyph<c=3,font=/CIDFont+F8> devidoglyph<c=3,font=/CIDFont+F8> aoglyph<c=3,font=/CIDFont+F8>'
# chunker.serialize(chunk) (283 tokens):
# '6. Recomendações de adubação e calagem para os citros\nAs fontes mais recomendadas de micronutrientes metálicos para aplicação foliar são sais solúveis formados com íons sulfato, cloreto ou nitrato. Para o Cu, a mistura de sulfato e hidróxido tem sido a forma mais eÀcienteglyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> fornecerglyph<c=3,font=/CIDFont+F8> oglyph<c=3,font=/CIDFont+F8> nutrienteglyph<c=3,font=/CIDFont+F8> eglyph<c=3,font=/CIDFont+F8> evitarglyph<c=3,font=/CIDFont+F8> Àtoxicidadeglyph<c=3,font=/CIDFont+F8> devidoglyph<c=3,font=/CIDFont+F8> aoglyph<c=3,font=/CIDFont+F8>'
#
# === 102 ===
# chunk.text (227 tokens):
# 'usoglyph<c=3,font=/CIDFont+F8> exclusivo na forma de sulfato. É importante ressaltar que o oxicloreto de Cu,glyph<c=3,font=/CIDFont+F8> comumenteglyph<c=3,font=/CIDFont+F8> utilizadoglyph<c=3,font=/CIDFont+F8> comoglyph<c=3,font=/CIDFont+F8> fungicida,glyph<c=3,font=/CIDFont+F8> temglyph<c=3,font=/CIDFont+F8> eÀciênciaglyph<c=3,font=/CIDFont+F8> limitadaglyph<c=3,font=/CIDFont+F8> comoglyph<c=3,font=/CIDFont+F8> fonte do nutriente.'
# chunker.serialize(chunk) (247 tokens):
# '6. Recomendações de adubação e calagem para os citros\nusoglyph<c=3,font=/CIDFont+F8> exclusivo na forma de sulfato. É importante ressaltar que o oxicloreto de Cu,glyph<c=3,font=/CIDFont+F8> comumenteglyph<c=3,font=/CIDFont+F8> utilizadoglyph<c=3,font=/CIDFont+F8> comoglyph<c=3,font=/CIDFont+F8> fungicida,glyph<c=3,font=/CIDFont+F8> temglyph<c=3,font=/CIDFont+F8> eÀciênciaglyph<c=3,font=/CIDFont+F8> limitadaglyph<c=3,font=/CIDFont+F8> comoglyph<c=3,font=/CIDFont+F8> fonte do nutriente.'
#
# === 103 ===
# chunk.text (156 tokens):
# 'As  soluções  para  pulverização  foliar  são  preparadas  com  ureia como coadjuvante (ureia a 2,5 g L -1 ) e os micronutrientes, na forma de sais de sulfato e ácido bórico nas seguintes concentrações (em mg L -1 de cada nutriente): B (200 a 300), Cu (100 a 125) Mn (300 a 700) e Zn (500 a 1.000). Nessa solução, para cada 1 kg de sulfato de Cu (pentahidratado) acrescentar  1,5  kg  de  hidróxido  de  Cu.  Essas  concentrações'
# chunker.serialize(chunk) (176 tokens):
# '6. Recomendações de adubação e calagem para os citros\nAs  soluções  para  pulverização  foliar  são  preparadas  com  ureia como coadjuvante (ureia a 2,5 g L -1 ) e os micronutrientes, na forma de sais de sulfato e ácido bórico nas seguintes concentrações (em mg L -1 de cada nutriente): B (200 a 300), Cu (100 a 125) Mn (300 a 700) e Zn (500 a 1.000). Nessa solução, para cada 1 kg de sulfato de Cu (pentahidratado) acrescentar  1,5  kg  de  hidróxido  de  Cu.  Essas  concentrações'
#
# === 104 ===
# chunk.text (280 tokens):
# 'foram deÀnidasglyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> fornecerglyph<c=3,font=/CIDFont+F8> anualmente,glyph<c=3,font=/CIDFont+F8> emglyph<c=3,font=/CIDFont+F8> trêsglyph<c=3,font=/CIDFont+F8> aplicaçõesglyph<c=3,font=/CIDFont+F8> foliares,glyph<c=3,font=/CIDFont+F8> asglyph<c=3,font=/CIDFont+F8> seguintes quantidades de micronutrientes: Cu (1,5 a 3,0 kg ha -1 , sulfato + hidróxido), Mn (1,8 a 4,2 kg ha -1 ) e Zn (3,0 a 6,0 kg ha -1 ). O volume ideal de calda para a aplicação desses micronutrientes é de aproximadamente 2.000 L ha -1 .'
# chunker.serialize(chunk) (300 tokens):
# '6. Recomendações de adubação e calagem para os citros\nforam deÀnidasglyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> fornecerglyph<c=3,font=/CIDFont+F8> anualmente,glyph<c=3,font=/CIDFont+F8> emglyph<c=3,font=/CIDFont+F8> trêsglyph<c=3,font=/CIDFont+F8> aplicaçõesglyph<c=3,font=/CIDFont+F8> foliares,glyph<c=3,font=/CIDFont+F8> asglyph<c=3,font=/CIDFont+F8> seguintes quantidades de micronutrientes: Cu (1,5 a 3,0 kg ha -1 , sulfato + hidróxido), Mn (1,8 a 4,2 kg ha -1 ) e Zn (3,0 a 6,0 kg ha -1 ). O volume ideal de calda para a aplicação desses micronutrientes é de aproximadamente 2.000 L ha -1 .'
#
# === 105 ===
# chunk.text (280 tokens):
# 'As menores concentrações de micronutrientes das recomendações acima são para a adubação de manutenção, enquanto as maiores são paraglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> correçãoglyph<c=3,font=/CIDFont+F8> dosglyph<c=3,font=/CIDFont+F8> sintomasglyph<c=3,font=/CIDFont+F8> visíveisglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> deÀciência.glyph<c=3,font=/CIDFont+F8> Asglyph<c=3,font=/CIDFont+F8> soluçõesglyph<c=3,font=/CIDFont+F8> maisglyph<c=3,font=/CIDFont+F8> concentradas devem ser aplicadas durante as horas mais frescas do dia ou à noite, evitando'
# chunker.serialize(chunk) (300 tokens):
# '6. Recomendações de adubação e calagem para os citros\nAs menores concentrações de micronutrientes das recomendações acima são para a adubação de manutenção, enquanto as maiores são paraglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> correçãoglyph<c=3,font=/CIDFont+F8> dosglyph<c=3,font=/CIDFont+F8> sintomasglyph<c=3,font=/CIDFont+F8> visíveisglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> deÀciência.glyph<c=3,font=/CIDFont+F8> Asglyph<c=3,font=/CIDFont+F8> soluçõesglyph<c=3,font=/CIDFont+F8> maisglyph<c=3,font=/CIDFont+F8> concentradas devem ser aplicadas durante as horas mais frescas do dia ou à noite, evitando'
#
# === 106 ===
# chunk.text (262 tokens):
# 'também mistura com óleos mineral ou vegetal para não causar queimaduras em folhas e frutos.\nPara as fontes de micronutrientes nas formas de cloreto ou nitrato, as concentrações acima indicadas devem ser reduzidas de 2 a 3 vezes; portanto,  número  maior  de  aplicações  será  necessário  para  manter  a dose anual do nutriente desejada.\nAdubaçãoglyph<c=3,font=/CIDFont+F5> foliarglyph<c=3,font=/CIDFont+F5> complementar: O  Mg  tem  sido  um nutriente pouco utilizado no manejo da adubação dos citros, apesar dos resultados de pesquisa que demonstram sua importância para a nutrição de plantas, aumento  da  produtividade  e  qualidade  dos  produtos.  A  adubação\nB-100, 2022\n197\n198\nBoletim 100: Recomendações de adubação e calagem para o estado de São Paulo'
# chunker.serialize(chunk) (282 tokens):
# '6. Recomendações de adubação e calagem para os citros\ntambém mistura com óleos mineral ou vegetal para não causar queimaduras em folhas e frutos.\nPara as fontes de micronutrientes nas formas de cloreto ou nitrato, as concentrações acima indicadas devem ser reduzidas de 2 a 3 vezes; portanto,  número  maior  de  aplicações  será  necessário  para  manter  a dose anual do nutriente desejada.\nAdubaçãoglyph<c=3,font=/CIDFont+F5> foliarglyph<c=3,font=/CIDFont+F5> complementar: O  Mg  tem  sido  um nutriente pouco utilizado no manejo da adubação dos citros, apesar dos resultados de pesquisa que demonstram sua importância para a nutrição de plantas, aumento  da  produtividade  e  qualidade  dos  produtos.  A  adubação\nB-100, 2022\n197\n198\nBoletim 100: Recomendações de adubação e calagem para o estado de São Paulo'
#
# === 107 ===
# chunk.text (280 tokens):
# 'foliarglyph<c=3,font=/CIDFont+F8> comglyph<c=3,font=/CIDFont+F8> oglyph<c=3,font=/CIDFont+F8> Mgglyph<c=3,font=/CIDFont+F8> églyph<c=3,font=/CIDFont+F8> umaglyph<c=3,font=/CIDFont+F8> estratégiaglyph<c=3,font=/CIDFont+F8> eÀcienteglyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> corrigirglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> deÀciênciaglyph<c=3,font=/CIDFont+F8> desse nutriente em citros, principalmente pela facilidade de aplicação e possibilidade de misturas com outros produtos na calda de pulverização. Recomenda-se'
# chunker.serialize(chunk) (300 tokens):
# '6. Recomendações de adubação e calagem para os citros\nfoliarglyph<c=3,font=/CIDFont+F8> comglyph<c=3,font=/CIDFont+F8> oglyph<c=3,font=/CIDFont+F8> Mgglyph<c=3,font=/CIDFont+F8> églyph<c=3,font=/CIDFont+F8> umaglyph<c=3,font=/CIDFont+F8> estratégiaglyph<c=3,font=/CIDFont+F8> eÀcienteglyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> corrigirglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> deÀciênciaglyph<c=3,font=/CIDFont+F8> desse nutriente em citros, principalmente pela facilidade de aplicação e possibilidade de misturas com outros produtos na calda de pulverização. Recomenda-se'
#
# === 108 ===
# chunk.text (53 tokens):
# 'a  aplicação  de  solução  com  5-10  kg  de  sulfato  de magnésio hidratado por 2.000 L da calda de pulverização, juntamente com as aplicações de micronutrientes.'
# chunker.serialize(chunk) (73 tokens):
# '6. Recomendações de adubação e calagem para os citros\na  aplicação  de  solução  com  5-10  kg  de  sulfato  de magnésio hidratado por 2.000 L da calda de pulverização, juntamente com as aplicações de micronutrientes.'
#
# === 109 ===
# chunk.text (279 tokens):
# 'Experimentos recentes em condições controladas com citros têm demonstradoglyph<c=3,font=/CIDFont+F8> queglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> adiçãoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> Moglyph<c=3,font=/CIDFont+F8> aumentaglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> eÀciênciaglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> usoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> N.glyph<c=3,font=/CIDFont+F8> Essas respostas poderão ocorrer em pomares com altas'
# chunker.serialize(chunk) (299 tokens):
# '6. Recomendações de adubação e calagem para os citros\nExperimentos recentes em condições controladas com citros têm demonstradoglyph<c=3,font=/CIDFont+F8> queglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> adiçãoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> Moglyph<c=3,font=/CIDFont+F8> aumentaglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> eÀciênciaglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> usoglyph<c=3,font=/CIDFont+F8> deglyph<c=3,font=/CIDFont+F8> N.glyph<c=3,font=/CIDFont+F8> Essas respostas poderão ocorrer em pomares com altas'
#
# === 110 ===
# chunk.text (280 tokens):
# 'produtividades, em solos com acidez moderada, arenosos e com baixo teor de matéria orgânica.glyph<c=3,font=/CIDFont+F8> Aglyph<c=3,font=/CIDFont+F8> adubaçãoglyph<c=3,font=/CIDFont+F8> foliarglyph<c=3,font=/CIDFont+F8> églyph<c=3,font=/CIDFont+F8> tambémglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> formaglyph<c=3,font=/CIDFont+F8> maisglyph<c=3,font=/CIDFont+F8> eÀcienteglyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> fornecer Mo para os citros. Nessas condições, recomenda-se de 2 a 3 aplicações anuais de solução contendo de 20 a 40'
# chunker.serialize(chunk) (300 tokens):
# '6. Recomendações de adubação e calagem para os citros\nprodutividades, em solos com acidez moderada, arenosos e com baixo teor de matéria orgânica.glyph<c=3,font=/CIDFont+F8> Aglyph<c=3,font=/CIDFont+F8> adubaçãoglyph<c=3,font=/CIDFont+F8> foliarglyph<c=3,font=/CIDFont+F8> églyph<c=3,font=/CIDFont+F8> tambémglyph<c=3,font=/CIDFont+F8> aglyph<c=3,font=/CIDFont+F8> formaglyph<c=3,font=/CIDFont+F8> maisglyph<c=3,font=/CIDFont+F8> eÀcienteglyph<c=3,font=/CIDFont+F8> paraglyph<c=3,font=/CIDFont+F8> fornecer Mo para os citros. Nessas condições, recomenda-se de 2 a 3 aplicações anuais de solução contendo de 20 a 40'
#
# === 111 ===
# chunk.text (49 tokens):
# 'mg L -1 de Mo, o que corresponde aproximadamente de 100 a 200 g de molibdato de amônio ou de sódio por 2.000 L de calda.\nB-100, 2022'
# chunker.serialize(chunk) (69 tokens):
# '6. Recomendações de adubação e calagem para os citros\nmg L -1 de Mo, o que corresponde aproximadamente de 100 a 200 g de molibdato de amônio ou de sódio por 2.000 L de calda.\nB-100, 2022'

# %%
import os
import json
import pandas as pd
from pdf2image import convert_from_path
from PyPDF2 import PdfReader
import pytesseract

# Configuração do Tesseract OCR (adicione o caminho do executável, se necessário)
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract.exe'

def is_readable_pdf(file_path):
    """Verifica se o PDF é legível ou contém imagens que necessitam OCR."""
    try:
        reader = PdfReader(file_path)
        first_page = reader.pages[0]
        text = first_page.extract_text()
        return text is not None and bool(text.strip())  # Retorna True se encontrar texto legível
    except Exception as e:
        print(f"Erro ao verificar o PDF {file_path}: {e}")
        return False

def extract_text_from_pdf(file_path):
    """Extrai texto diretamente de um PDF legível."""
    text = []
    try:
        reader = PdfReader(file_path)
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                text.append(page_text)
    except Exception as e:
        print(f"Erro ao extrair texto do PDF {file_path}: {e}")
    return "\n".join(text)

def perform_ocr_on_pdf(file_path):
    """Realiza OCR em um PDF baseado em imagens."""
    ocr_text = []
    try:
        images = convert_from_path(file_path)
        for image in images:
            ocr_text.append(pytesseract.image_to_string(image))
    except Exception as e:
        print(f"Erro ao realizar OCR no PDF {file_path}: {e}")
    return "\n".join(ocr_text)

def save_to_files(text, output_prefix):
    """Salva o texto extraído em formatos JSON, Markdown, CSV."""
    # JSON
    json_path = f"{output_prefix}.json"
    with open(json_path, "w", encoding="utf-8") as json_file:
        json.dump({"text": text}, json_file, ensure_ascii=False, indent=4)
    
    # Markdown
    markdown_path = f"{output_prefix}.md"
    with open(markdown_path, "w", encoding="utf-8") as md_file:
        md_file.write(text)
    
    # CSV
    csv_path = f"{output_prefix}.csv"
    df = pd.DataFrame([{"content": text}])
    df.to_csv(csv_path, index=False, encoding="utf-8")
    
    print(f"Resultados salvos como JSON: {json_path}, Markdown: {markdown_path}, CSV: {csv_path}")

def process_documents(file_paths):
    """Processa uma lista de documentos PDF e salva os resultados."""
    for file_path in file_paths:
        print(f"Processando: {file_path}")
        if is_readable_pdf(file_path):
            print("PDF legível detectado.")
            extracted_text = extract_text_from_pdf(file_path)
        else:
            print("PDF baseado em imagens detectado. Iniciando OCR.")
            extracted_text = perform_ocr_on_pdf(file_path)
        
        # Definir o prefixo de saída
        output_prefix = os.path.splitext(os.path.basename(file_path))[0]
        save_to_files(extracted_text, output_prefix)

# Caminhos dos PDFs de exemplo
pdf_paths = [
    r"C:\Estudos e Projetos\(2024) LLM Agrônomo Virtual\1 - criação_base\page_1.pdf",
]

# Processar os PDFs
process_documents(pdf_paths)

# %%
# salva uma página

from PIL import Image
import fitz
import os

# Caminho do PDF
source = r"C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\pdf\citros.pdf"

# Abrir o documento PDF
pdf_document = fitz.open(source)

# Criar diretório para salvar as imagens, se não existir
output_dir = r"C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base"
os.makedirs(output_dir, exist_ok=True)

# Salvar cada página como uma imagem em preto e branco com 300 DPI
for i in range(len(pdf_document)):
    page = pdf_document.load_page(i)
    pix = page.get_pixmap(dpi=300)
    image = Image.frombytes("RGB", (pix.width, pix.height), pix.samples)
    bw_image = image.convert("L")  # Converter para preto e branco
    image_path = os.path.join(output_dir, f"page_{i + 1}.png")
    bw_image.save(image_path, dpi=(300, 300))
    print(f"Página {i + 1} salva como {image_path}")
# Out:
# Página 1 salva como C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base\page_1.png
# Página 2 salva como C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base\page_2.png
# Página 3 salva como C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base\page_3.png
# Página 4 salva como C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base\page_4.png
# Página 5 salva como C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base\page_5.png
# Página 6 salva como C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base\page_6.png
# Página 7 salva como C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base\page_7.png
# Página 8 salva como C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base\page_8.png
# Página 9 salva como C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base\page_9.png
# Página 10 salva como C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base\page_10.png
# Página 11 salva como C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base\page_11.png
# Página 12 salva como C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base\page_12.png

# %%
## salva com todas as páginas
from PIL import Image
import fitz
import os

# Caminho do PDF
source = r"C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\pdf\citros.pdf"

# Abrir o documento PDF
pdf_document = fitz.open(source)

# Criar diretório para salvar as imagens, se não existir
output_dir = r"C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base"
os.makedirs(output_dir, exist_ok=True)

# Lista para armazenar as imagens das páginas
images = []

# Salvar cada página como uma imagem em preto e branco com 300 DPI
for i in range(len(pdf_document)):
    page = pdf_document.load_page(i)
    pix = page.get_pixmap(dpi=300)
    image = Image.frombytes("RGB", (pix.width, pix.height), pix.samples)
    bw_image = image.convert("L")  # Converter para preto e branco
    images.append(bw_image)

# Combinar todas as imagens verticalmente
total_height = sum(image.height for image in images)
max_width = max(image.width for image in images)
combined_image = Image.new('L', (max_width, total_height))

y_offset = 0
for image in images:
    combined_image.paste(image, (0, y_offset))
    y_offset += image.height

# Salvar a imagem combinada
combined_image_path = os.path.join(output_dir, "combined_pages.png")
combined_image.save(combined_image_path, dpi=(300, 300))
print(f"Todas as páginas salvas como {combined_image_path}")

# %%
import os
from pdf2image import convert_from_path
import pytesseract

# Configuração do Tesseract OCR (adicione o caminho do executável, se necessário)
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract.exe'

def perform_ocr_on_pdf(file_path):
    """Realiza OCR em um PDF baseado em imagens e imprime o texto extraído."""
    ocr_text = []
    try:
        images = convert_from_path(file_path)
        for image in images:
            text = pytesseract.image_to_string(image)
            ocr_text.append(text)
            print(text)  # Imprime o texto extraído de cada página
    except Exception as e:
        print(f"Erro ao realizar OCR no PDF {file_path}: {e}")
    return "\n".join(ocr_text)

# Caminho do PDF de exemplo
pdf_path = r"C:\Estudos e Projetos\(2024) LLM Agrônomo Virtual\1 - criação_base\page_1.pdf"

# Realizar OCR no PDF e imprimir o texto extraído
perform_ocr_on_pdf(pdf_path)
