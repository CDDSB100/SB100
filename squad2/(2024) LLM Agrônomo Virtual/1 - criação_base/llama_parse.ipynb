# %% [markdown]
# #### Modelo para transformar PDF em arquivos markdown

# %% [markdown]
# ##### Instalação

# %%
#!pip install llama-parse

# %% [markdown]
# ##### Carrega documento

# %%
import nest_asyncio
nest_asyncio.apply()

## podemos usar uma chave da OpenAI
import os
os.environ['LLAMA_CLOUD_API_KEY'] = 'llx-'

# %%
# chama biblioteca
from llama_parse import LlamaParse

# extração de dados de um documento PDF
documento = LlamaParse(result_type="markdown",
                       verbose=True,
                       language='pt',
                       #disable_ocr=True,
                       # podemos especificar as páginas que queremos extrair os dados
                       #target_pages="0,2,7",
                       ## podemos especificar a área da página que queremos extrair os dados entre 0 e 1
                       ## bbox_left, bbox_right, bbox_tope, bbox_bottom
                       ## Essa configuração abaixo é para os modelos de artigos do IAC
                       bounding_box="0.1, 0.09, 0.2, 0.1",
                       ).load_data(r"C:\Estudos e Projetos\(2024) LLM Agrônomo Virtual\pdf\0000444-08.2022.8.26.0052_relatório_final_pags_73-77.pdf")

# imprime os dados do documento
documento
# Out:
# Started parsing the file under job_id 422c8a05-d0ea-456a-a12f-7602b6f90cc1
# ...

# %%
## salvar aquivo
nome_do_arquivo = "outro.md"

with open(nome_do_arquivo, "w") as arquivo:
    for item in documento:
        arquivo.write(item.text)

# %% [markdown]
# ### <b>Mostrando a tabela 1 (formato markdown)</b>

# %%
print(documento[1].text[0:])
# Out:
# # Boletim 100: Recomendações de adubação e calagem para o estado de São Paulo
#
# quantidades de nutrientes exportadas com a colheita de frutas cítricas. Esses valores se aplicam para pomares com produtividades de 30 a 60 t ha-1 de frutos.
#
# # Tabela 1. Conteúdo de nutrientes exportado por tonelada de fruto colhido
#
# | |N|P|K|Ca|Mg|S|
# |---|---|---|---|---|---|---|
# |Citros|1,9-2,4|0,15-0,21|1,3-2,1|0,45-0,64|0,11-0,15|0,10-0,18|
#
#
# | |B|Cu|Fe|Mn|Zn|
# |---|---|---|---|---|---|
# |Citros|2,0-6,0|0,4-0,7|3,0-5,0|1,0-3,0|1,0-3,0|
#
# # 3. Amostragem e análise química de folha
#
# ...

# %% [markdown]
# #### <b>Mostrando a tabela 2</b>

# %%
print(documento[2].text[0:])
# Out:
# # Citros
#
# superfície do limbo foliar por vários meses e levar ao erro de interpretação da análise; assim, quando possível, é recomendável não coletar folhas em um intervalo mínimo 30 dias após a última pulverização. As amostras devem ser acondicionadas em sacos de papel e enviadas para o laboratório em período inferior a dois dias após a coleta no campo.
#
# Os valores de concentrações de nutrientes nas folhas de citros e suas interpretações estão na tabela 2.
#
# # Tabela 2
#
# Faixas para interpretação de teores de macro e micronutrientes nas folhas de citros, geradas na primavera, com seis meses de idade, de ramos com fruto terminal com 2 a 4 cm de diâmetro
#
# |Nutriente|Baixo|Adequado|Alto|
# |---|---|---|---|
# |N: Citros geral|&lt;25|25-30|&gt;30|
# |N: Limões e lima ácida Tahiti|&lt;20|20-24|&gt;24|
# |P|&lt;1,2|1,2-1,6|&gt;1,6|
# |K|&lt;10|10-15|&gt;15|
# |Ca|&lt;35|35-50|&gt;50|
# |Mg|&lt;3,5|3,5-5,0|&gt;5,0|
# |S|&lt;2,0|2,0-3,0|&gt;3,0|
# |B|&lt;50|50-150|&gt;150|
# ...

# %% [markdown]
# #### Salva o trecho da tabela 2

# %%
nome_do_arquivo = "citrus_tabela_2.md"

with open(nome_do_arquivo, "w") as arquivo:
    arquivo.write(documento[2].text)

# %%
documento_com_instrucoes = LlamaParse(
    result_type="markdown",
    parsing_instruction="""
    Este é um teste com o pdf de citros.
    """
    ).load_data("C:/Estudos e Projetos/(2024) LLM Agrônomo Virtual/citros.pdf")
# Out:
# Started parsing the file under job_id 7e036b82-40b0-4ec9-8fbf-6a2b8b0b2586
# .

# %%
nome_do_arquivo = "citrus_teste_com_estrutura.md"

with open(nome_do_arquivo, "w") as arquivo:
    for item in documento:
        arquivo.write(item.text)
