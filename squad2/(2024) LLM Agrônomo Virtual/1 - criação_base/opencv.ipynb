# %%
import pytesseract
import cv2

# %%
import os
import json
import pandas as pd
from pdf2image import convert_from_path
from PyPDF2 import PdfReader
import pytesseract

# Configuração do Tesseract OCR (adicione o caminho do executável, se necessário)
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract.exe'


imagem = cv2.imreadmulti(r'C:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\1 - criação_base\page_1.png')

# Verifica se a imagem foi carregada corretamente
if imagem is not None:
	texto = pytesseract.image_to_string(imagem)
	print(texto)
else:
	print("Erro ao carregar a imagem. Verifique o caminho do arquivo.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 16
#      14 # Verifica se a imagem foi carregada corretamente
#      15 if imagem is not None:
# ---> 16 	texto = pytesseract.image_to_string(imagem)
#      17 	print(texto)
#      18 else:
#
# File c:\Estudos e Projetos\2024-LLM-Agronomo-Virtual\.venv\Lib\site-packages\pytesseract\pytesseract.py:486, in image_to_string(image, lang, config, nice, output_type, timeout)
#     481 """
#     482 Returns the result of a Tesseract OCR run on the provided image to string
#     483 """
#     484 args = [image, 'txt', lang, config, nice, timeout]
# --> 486 return {
#     487     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     489     Output.STRING: lambda: run_and_get_output(*args),
#     490 }[output_type]()
#
# ...
